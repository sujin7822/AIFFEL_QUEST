# %% [markdown]
# ## 데이터 다운로드

# %%
# import shutil

# filename = 'archive.zip'
# extract_dir = 'archive'
# archive_format = 'zip'

# shutil.unpack_archive(filename, extract_dir, archive_format)

# %%
import os
from PIL import Image
import matplotlib.pyplot as plt

# 이미지 파일 경로
image_directory = '/aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images'

# 이미지 파일 목록
image_files = [os.path.join(image_directory, filename) for filename in os.listdir(image_directory) if filename.endswith('.png')]

# 이미지 파일 로드
images = [Image.open(image_file) for image_file in image_files]

# 이미지 표시
plt.imshow(images[0])
plt.axis('off')  # 이미지 축 제거
plt.show()

# %%
# 이미지 파일 수
num_images = len(image_files)

# 이미지 파일 이름 출력
print("Image Files:")
for image_file in image_files:
    print(image_file)

# 이미지 파일 수 출력
print(f"Total number of images: {num_images}")
# Out:
# Image Files:
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (75).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (28).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (20).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (412).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (40).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (57).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (77).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (418).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (35).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (317).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (310).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (428).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (435).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (424).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (366).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (354).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (29).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (30).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (76).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (84).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (373).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (447).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (80).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (87).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (91).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (440).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (95).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (406).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (71).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (21).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (92).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (376).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (421).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (77).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (372).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (433).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (388).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (48).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (55).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (363).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (100).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (414).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (39).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (435).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (359).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (62).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (373).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (424).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (319).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (391).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (31).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (407).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (387).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (39).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (383).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (82).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (40).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (49).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (70).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (318).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (317).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (389).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (369).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (72).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (90).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (34).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (99).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (355).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (321).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (66).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (14).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (27).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (446).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (430).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (393).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (309).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (419).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (68).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (422).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (394).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (42).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (355).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (426).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (29).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (413).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (370).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (81).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (443).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (79).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (89).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (69).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (73).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (86).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (366).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (435).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (57).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (431).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (439).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (392).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (67).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (69).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (33).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (55).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (361).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (442).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (25).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (354).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (98).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (438).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (401).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (28).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (378).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (69).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (368).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (10).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (61).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (357).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (56).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (377).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (56).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (11).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (74).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (26).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (378).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (395).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (364).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (12).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (354).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (369).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (17).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (413).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (48).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (445).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (87).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (314).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (96).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (416).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (84).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (362).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (33).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (357).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (391).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (400).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (95).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (17).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (358).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (65).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (443).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (54).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (313).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (8).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (322).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (18).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (449).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (386).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (54).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (356).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (375).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (426).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (437).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (75).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (408).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (438).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (90).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (417).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (323).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (85).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (78).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (322).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (353).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (13).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (50).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (428).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (86).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (311).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (394).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (312).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (11).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (36).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (47).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (378).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (416).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (53).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (409).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (384).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (21).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (396).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (94).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (389).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (356).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (93).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (428).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (52).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (85).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (21).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (419).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (359).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (321).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (58).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (10).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (375).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (377).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (416).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (441).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (326).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (418).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (355).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (47).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (424).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (45).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (314).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (20).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (311).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (81).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (358).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (417).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (440).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (317).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (91).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (19).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (445).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (407).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (73).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (309).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (45).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (36).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (433).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (16).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (436).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (313).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (353).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (15).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (408).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (34).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (63).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (436).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (381).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (375).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (356).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (14).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (52).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (385).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (436).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (446).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (312).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (71).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (390).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (33).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (26).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (325).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (384).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (418).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (324).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (429).png.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (429).png.png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (405).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (44).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (420).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (310).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (43).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (96).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (62).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (439).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (48).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (420).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (66).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (67).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (38).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (447).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (387).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (442).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (38).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (405).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (380).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (98).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (437).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (35).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (35).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (326).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (74).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (96).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (444).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (441).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (412).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (49).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (60).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (78).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (60).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (444).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (99).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (99).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (82).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (90).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (379).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (36).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (386).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (8).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (37).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (41).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (392).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (46).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (311).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (413).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (86).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (23).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (410).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (46).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (82).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (398).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (437).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (370).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (79).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (318).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (367).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (89).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (411).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (404).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (324).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (76).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (54).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (30).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (14).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (61).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (94).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (15).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (397).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (446).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (425).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (63).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (26).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (85).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (450).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (57).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (434).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (52).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (89).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (325).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (385).png___fuse.png
# ...
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (319).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (440).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (441).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (47).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (53).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (322).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (421).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (325).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (10).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (97).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (407).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (381).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (422).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (43).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (88).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (448).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (75).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (80).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (433).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (314).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (97).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (417).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (59).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (447).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (29).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (443).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (371).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (41).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (81).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (59).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (50).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (8).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (393).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (414).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (62).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (7).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (77).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (358).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (51).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (364).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (22).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (318).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (37).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (13).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (431).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (439).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (403).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (426).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (398).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (448).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (17).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (64).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (364).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (353).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (95).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (71).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (379).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (368).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (400).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (442).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (31).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (63).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (30).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (324).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (372).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (51).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (419).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (406).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (98).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (388).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (434).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (46).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (414).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (64).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (427).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (18).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (28).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (390).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (403).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (410).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (60).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (55).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (64).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (404).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (372).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (9).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (19).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (368).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (406).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (91).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (405).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (15).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (88).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (380).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (408).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (369).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (432).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (359).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (423).png.png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (24).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (374).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (370).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (34).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (361).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (44).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (397).png___save.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (429).png.png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (367).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (434).png___fuse.png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/night ride (9).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (383).png
# /aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images/Screenshot (384).png
# Total number of images: 600

# %%
# 이미지 데이터를 저장할 변수 초기화
images_data = []
fuse_data = []
save_data = []

# 원본 이미지 파일 경로
image_dir = '/aiffel/aiffel/AIFFEL_Quest/Main_Quest2/archive/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/images'

# 이미지 파일 목록을 가져오기
image_files = os.listdir(image_dir)

# 이미지 파일을 images_data, fuse_data, save_data로 나누어 저장
for image_file in image_files:
    if "___fuse.png" in image_file:
        fuse_data.append(image_file)
    elif "___save.png" in image_file:
        save_data.append(image_file)
    else:
        images_data.append(image_file)

# 출력 변수를 사용할 수 있습니다.
print("Images Data:", len(images_data))
print("Fuse Data:", len(fuse_data))
print("Save Data:", len(save_data))
# Out:
# Images Data: 200
# Fuse Data: 200
# Save Data: 200

# %% [markdown]
# **600개의 데이터가 있다.**

# %% [markdown]
# ## 데이터 전처리

# %% [markdown]
# 1. np

# %%
from PIL import Image
import numpy as np

input_size = (128, 128)
def change_file_to_np(image_files, batch_size=32):
    images_np = []
    num_images = len(image_files)
    num_batches = (num_images + batch_size - 1) // batch_size

    for batch_idx in range(num_batches):
        start_idx = batch_idx * batch_size
        end_idx = min((batch_idx + 1) * batch_size, num_images)

        batch_image_files = image_files[start_idx:end_idx]
        batch_images_np = []

        for image_file in batch_image_files:
            image_path = os.path.join(image_dir, image_file)
            image_pil = Image.open(image_path).convert("RGB")  # Convert image to RGB
            image_pil_resized = image_pil.resize(input_size)
            image_np = np.array(image_pil_resized) / 255.0
            batch_images_np.append(image_np)

        batch_images_np = np.array(batch_images_np)
        images_np.extend(batch_images_np)

    images_np = np.stack(images_np, axis=0)
    return images_np

# 이미지 파일명을 리스트로 저장
image_files = os.listdir(image_dir)

# 이미지 데이터를 numpy 배열로 변환
images_np = change_file_to_np(images_data)
fuse_np = change_file_to_np(fuse_data)
save_np = change_file_to_np(save_data)

# %% [markdown]
# **images_np와 fuse_np 사용!**

# %% [markdown]
# 2. 데이터 분할

# %%
from sklearn.model_selection import train_test_split

# images_np, fuse_np 데이터를 train과 test로 분할
train_images, test_images, train_fuse, test_fuse = train_test_split(images_np, fuse_np, test_size=0.2, random_state=42)

# 분할된 데이터의 크기 확인
print("Train images shape:", train_images.shape)
print("Test images shape:", test_images.shape)
print("Train fuse shape:", train_fuse.shape)
print("Test fuse shape:", test_fuse.shape)
# Out:
# Train images shape: (160, 128, 128, 3)
# Test images shape: (40, 128, 128, 3)
# Train fuse shape: (160, 128, 128, 3)
# Test fuse shape: (40, 128, 128, 3)

# %%
import matplotlib.pyplot as plt

# train 데이터 중 첫 번째 이미지와 fuse를 선택
train_image_0 = train_images[0]
train_fuse_0 = train_fuse[0]

# test 데이터 중 첫 번째 이미지와 fuse를 선택
test_image_0 = test_images[0]
test_fuse_0 = test_fuse[0]

# 시각화
plt.figure(figsize=(12, 6))

# Train 데이터
plt.subplot(2, 2, 1)
plt.imshow(train_image_0)
plt.title("Train Image")

plt.subplot(2, 2, 2)
plt.imshow(train_fuse_0)
plt.title("Train Fuse")

# Test 데이터
plt.subplot(2, 2, 3)
plt.imshow(test_image_0)
plt.title("Test Image")

plt.subplot(2, 2, 4)
plt.imshow(test_fuse_0)
plt.title("Test Fuse")

plt.show()

# %% [markdown]
# ## 모델 설계
#
# 1024까지 층을 쌓아보자
#
# Dropout과 BatchNormalization을 활용해 성능을 높여보자

# %% [markdown]
# U-Net 인코더

# %%
from keras.layers import Layer

class Encoder(Layer):
    
    def __init__(self, filters, rate=0.2, pooling=True, **kwargs):
        super(Encoder, self).__init__(**kwargs)
        
        self.filters = filters
        self.rate = rate
        self.pooling = pooling
        
        self.bn = BatchNormalization()
        self.c1 = Conv2D(filters, kernel_size=3, strides=1, padding='same', activation='relu', kernel_initializer='he_normal')
        self.drop = Dropout(rate)
        self.c2 = Conv2D(filters, kernel_size=3, strides=1, padding='same', activation='relu', kernel_initializer='he_normal')
        self.pool = MaxPool2D()
    
    def call(self, X):
        x = self.c2(self.drop(self.c1(self.bn(X))))
        if self.pooling:
            y = self.pool(x)
            return x, y
        return x
    
    def get_config(self):
        base_config = super().get_config()
        return {**base_config, "filters":self.filters, "rate":self.rate,"pooling":self.pooling}

# %% [markdown]
# U-Net 디코더

# %%
class Decoder(Layer):
    
    def __init__(self, filters, rate, **kwargs):
        super(Decoder, self).__init__(**kwargs)
        
        self.filters = filters
        self.rate = rate
        
        self.cT = Conv2DTranspose(filters, kernel_size=3, strides=2, padding='same', activation='relu', kernel_initializer='he_normal')
        self.bn = BatchNormalization()
        self.skip = Concatenate()
        self.net = Encoder(filters, rate, pooling=False)
    
    def call(self, X):
        x, skip_x = X
        y = self.cT(self.bn(x))
        y = self.net(self.skip([y, skip_x]))
        return y
    
    def get_config(self):
        base_config = super().get_config()
        return {**base_config, "filters":self.filters, "rate":self.rate}

# %% [markdown]
# U-Net

# %%
from keras.layers import Input
from keras.layers import BatchNormalization
from keras.layers import Conv2D
from keras.layers import Dropout
from keras.layers import MaxPool2D
from tensorflow.keras.layers import Conv2DTranspose
from tensorflow.keras.layers import Concatenate
from tensorflow.keras.models import Model

InputL = Input(shape=(128,128,3), name="InputImage")

# Encoder Block 
c1, p1 = Encoder(filters=64,  rate=0.1, name="Encoder1")(InputL)
c2, p2 = Encoder(filters=128, rate=0.1, name="Encoder2")(p1)
c3, p3 = Encoder(filters=256, rate=0.2, name="Encoder3")(p2)
c4, p4 = Encoder(filters=512, rate=0.2, name="Encoder4")(p3)
c5, p5 = Encoder(filters=1024, rate=0.2, name="Encoder5")(p4)

# Encoding Layer
encodings = Encoder(filters=1024, rate=0.3, pooling=False, name="Encoding")(p5)

# Decoder Block
d = Decoder(1024, 0.2, name='Decoder1')([encodings, c5])
d = Decoder(512, 0.2, name='Decoder2')([d, c4])
d = Decoder(256, 0.2, name='Decoder3')([d, c3])
d = Decoder(128, 0.1, name='Decoder4')([d, c2])
d = Decoder(64, 0.1, name='Decoder5')([d, c1])

# Output
conv_out = Conv2D(3, kernel_size=3, padding='same', activation='sigmoid', name="Segmentator")(d)

# Model
model = Model(InputL, conv_out, name="UNet")
model.summary()

# Compile Model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# Model: "UNet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# InputImage (InputLayer)         [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# Encoder1 (Encoder)              ((None, 128, 128, 64 38732       InputImage[0][0]
# __________________________________________________________________________________________________
# Encoder2 (Encoder)              ((None, 64, 64, 128) 221696      Encoder1[0][1]
# __________________________________________________________________________________________________
# Encoder3 (Encoder)              ((None, 32, 32, 256) 885760      Encoder2[0][1]
# __________________________________________________________________________________________________
# Encoder4 (Encoder)              ((None, 16, 16, 512) 3540992     Encoder3[0][1]
# __________________________________________________________________________________________________
# Encoder5 (Encoder)              ((None, 8, 8, 1024), 14159872    Encoder4[0][1]
# __________________________________________________________________________________________________
# Encoding (Encoder)              (None, 4, 4, 1024)   18880512    Encoder5[0][1]
# __________________________________________________________________________________________________
# Decoder1 (Decoder)              (None, 8, 8, 1024)   37764096    Encoding[0][0]
#                                                                  Encoder5[0][0]
# __________________________________________________________________________________________________
# Decoder2 (Decoder)              (None, 16, 16, 512)  11806208    Decoder1[0][0]
#                                                                  Encoder4[0][0]
# __________________________________________________________________________________________________
# Decoder3 (Decoder)              (None, 32, 32, 256)  2953984     Decoder2[0][0]
#                                                                  Encoder3[0][0]
# __________________________________________________________________________________________________
# Decoder4 (Decoder)              (None, 64, 64, 128)  739712      Decoder3[0][0]
#                                                                  Encoder2[0][0]
# __________________________________________________________________________________________________
# Decoder5 (Decoder)              (None, 128, 128, 64) 185536      Decoder4[0][0]
#                                                                  Encoder1[0][0]
# __________________________________________________________________________________________________
# Segmentator (Conv2D)            (None, 128, 128, 3)  1731        Decoder5[0][0]
# ==================================================================================================
# Total params: 91,178,831
# Trainable params: 91,161,033
# Non-trainable params: 17,798
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model

plot_model(model, "UNet.png", show_shapes=True)

# %% [markdown]
# ## 모델 훈련하기

# %%
BATCH_SIZE = 16
SPE = len(images)//BATCH_SIZE

# %%
def show_image(image, title=None):
    plt.imshow(image)
    plt.title(title)
    plt.axis('off')

# %%
from keras.callbacks import Callback, ModelCheckpoint

# class ShowProgress(Callback):
#     def on_epoch_end(self, epoch, logs=None):
#         id = np.random.randint(len(train_images))
#         images = train_images[id]
#         fuse = train_fuse[id]
#         pred_mask = self.model(tf.expand_dims(image,axis=0))[0]
        
#         plt.figure(figsize=(10,8))
#         plt.subplot(1,3,1)
#         show_image(image, title="Original Image")
        
#         plt.subplot(1,3,2)
#         show_image(mask, title="Original Mask")
        
#         plt.subplot(1,3,3)
#         show_image(pred_mask, title="Predicted Mask")
            
#         plt.tight_layout()
#         plt.show()

# %% [markdown]
# **콜백함수 사용해서 결과 가장 좋을때의 에폭 저장**

# %%
cbs = [ModelCheckpoint("UNet-Pascal-VOC-image-Segmentation.h5", save_best_only=True)]

# %%
train_images.shape
# Out:
# (160, 128, 128, 3)

# %%
train_fuse.shape
# Out:
# (160, 128, 128, 3)

# %%
history = model.fit(
                    train_images, train_fuse,
                    validation_split=0.1,
                    epochs=50,
                    batch_size=BATCH_SIZE,
                    steps_per_epoch=SPE,
                    callbacks=cbs
)
# Out:
# Epoch 1/50
# 37/37 [==============================] - 56s 353ms/step - loss: 0.6198 - accuracy: 0.5872 - val_loss: 46.9416 - val_accuracy: 0.6326
# Epoch 2/50
# 37/37 [==============================] - 13s 339ms/step - loss: 0.5781 - accuracy: 0.6591 - val_loss: 1.0305 - val_accuracy: 0.6351
# Epoch 3/50
# 37/37 [==============================] - 13s 337ms/step - loss: 0.5747 - accuracy: 0.6588 - val_loss: 0.6395 - val_accuracy: 0.6325
# Epoch 4/50
# 37/37 [==============================] - 13s 339ms/step - loss: 0.5716 - accuracy: 0.6653 - val_loss: 0.7394 - val_accuracy: 0.6393
# Epoch 5/50
# 37/37 [==============================] - 13s 342ms/step - loss: 0.5712 - accuracy: 0.6672 - val_loss: 0.6598 - val_accuracy: 0.6484
# Epoch 6/50
# 37/37 [==============================] - 13s 344ms/step - loss: 0.5682 - accuracy: 0.6670 - val_loss: 0.6321 - val_accuracy: 0.6230
# Epoch 7/50
# 37/37 [==============================] - 13s 344ms/step - loss: 0.5673 - accuracy: 0.6663 - val_loss: 0.6201 - val_accuracy: 0.6426
# Epoch 8/50
# 37/37 [==============================] - 13s 344ms/step - loss: 0.5635 - accuracy: 0.6743 - val_loss: 0.6218 - val_accuracy: 0.6288
# Epoch 9/50
# 37/37 [==============================] - 13s 349ms/step - loss: 0.5608 - accuracy: 0.6769 - val_loss: 0.6421 - val_accuracy: 0.6782
# Epoch 10/50
# 37/37 [==============================] - 13s 350ms/step - loss: 0.5596 - accuracy: 0.6801 - val_loss: 0.6242 - val_accuracy: 0.6142
# Epoch 11/50
# 37/37 [==============================] - 13s 354ms/step - loss: 0.5557 - accuracy: 0.6853 - val_loss: 0.6032 - val_accuracy: 0.6263
# Epoch 12/50
# 37/37 [==============================] - 13s 344ms/step - loss: 0.5521 - accuracy: 0.6936 - val_loss: 0.6206 - val_accuracy: 0.6243
# Epoch 13/50
#  6/37 [===>..........................] - ETA: 10s - loss: 0.5529 - accuracy: 0.6826WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 1850 batches). You may need to use the repeat() function when building your dataset.
# 37/37 [==============================] - 4s 113ms/step - loss: 0.5529 - accuracy: 0.6826 - val_loss: 0.6296 - val_accuracy: 0.6547

# %%
import matplotlib.pyplot as plt

# 손실 그래프
epochs = range(2, len(history.history["loss"]) + 1)
loss = history.history["loss"][1:] # 1의 손실 함수가 너무 커서 제외
val_loss = history.history["val_loss"][1:]

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 2)
plt.plot(epochs, loss, "b", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss", color = 'red')
plt.title("Training and validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

# 정확도 그래프
acc = history.history["accuracy"][1:]
val_acc = history.history["val_accuracy"][1:]

plt.subplot(1, 2, 1)
plt.plot(epochs, acc, "b", label="Training accuracy")
plt.plot(epochs, val_acc, "b", label="Validation accuracy", color = 'red')
plt.title("Training and validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()

plt.show()
# Out:
# /tmp/ipykernel_791/2703338607.py:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.0, 0.0, 1.0, 1)). The keyword argument will take precedence.
#   plt.plot(epochs, val_loss, "b", label="Validation loss", color = 'red')
# /tmp/ipykernel_791/2703338607.py:23: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.0, 0.0, 1.0, 1)). The keyword argument will take precedence.
#   plt.plot(epochs, val_acc, "b", label="Validation accuracy", color = 'red')

# %%
# 테스트 데이터로 모델 평가
test_loss, test_accuracy = model.evaluate(test_images, test_fuse)

# 평가 결과 출력
print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
# Out:
# 2/2 [==============================] - 10s 2s/step - loss: 0.6156 - accuracy: 0.6681
# Test Loss: 0.6156219244003296
# Test Accuracy: 0.6681228876113892

# %%
# 이미지 데이터의 형태 확인
print(test_images.shape)  # (40, 128, 128, 3)

# 모델을 사용하여 테스트 이미지에 대한 예측 생성
pred = model.predict(test_images)

# 첫 번째 이미지 선택하여 출력
plt.figure(figsize=(20, 10))
plt.subplot(1, 3, 1); plt.imshow(test_images[0]); plt.title('Input Image', fontsize=20)
plt.subplot(1, 3, 2); plt.imshow(pred[0]); plt.title('Predicted Image', fontsize=20)
plt.subplot(1, 3, 3); plt.imshow(test_fuse[0]); plt.title('Fuse Image', fontsize=20)
plt.show()
# Out:
# (40, 128, 128, 3)

# %% [markdown]
# 아직 overfitting도 일어나지 않은 것 같다.
#
# 에폭을 더 많이 돌려봐야겠다.
#
# 콜백 조기종료를 없애고 다시 시도해 봐야겠다.

# %% [markdown]
# ## 성능 향상을 위한 시도!!

# %% [markdown]
# 데이터 수에 비해 모델이 너무 깊은 느낌이다.
#
# dropout을 0.5로 해보자.
#
# 층도 줄여보자.

# %%
from keras.layers import Input
from keras.layers import BatchNormalization
from keras.layers import Conv2D
from keras.layers import Dropout
from keras.layers import MaxPool2D
from tensorflow.keras.layers import Conv2DTranspose
from tensorflow.keras.layers import Concatenate
from tensorflow.keras.models import Model

InputL = Input(shape=(128,128,3), name="InputImage")

# Encoder Block 
c1, p1 = Encoder(filters=64,  rate=0.5, name="Encoder1")(InputL)
c2, p2 = Encoder(filters=128, rate=0.5, name="Encoder2")(p1)
c3, p3 = Encoder(filters=256, rate=0.5, name="Encoder3")(p2)
c4, p4 = Encoder(filters=512, rate=0.5, name="Encoder4")(p3)

# Encoding Layer
encodings = Encoder(filters=512, rate=0.5, pooling=False, name="Encoding")(p4)

# Decoder Block
d = Decoder(512, 0.5, name='Decoder1')([encodings, c4])
d = Decoder(256, 0.5, name='Decoder2')([d, c3])
d = Decoder(128, 0.5, name='Decoder3')([d, c2])
d = Decoder(64, 0.5, name='Decoder4')([d, c1])

# Output
conv_out = Conv2D(3, kernel_size=3, padding='same', activation='sigmoid', name="Segmentator")(d)

# Model
model = Model(InputL, conv_out, name="UNet")
model.summary()

# Compile Model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# Model: "UNet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# InputImage (InputLayer)         [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# Encoder1 (Encoder)              ((None, 128, 128, 64 38732       InputImage[0][0]
# __________________________________________________________________________________________________
# Encoder2 (Encoder)              ((None, 64, 64, 128) 221696      Encoder1[0][1]
# __________________________________________________________________________________________________
# Encoder3 (Encoder)              ((None, 32, 32, 256) 885760      Encoder2[0][1]
# __________________________________________________________________________________________________
# Encoder4 (Encoder)              ((None, 16, 16, 512) 3540992     Encoder3[0][1]
# __________________________________________________________________________________________________
# Encoding (Encoder)              (None, 8, 8, 512)    4721664     Encoder4[0][1]
# __________________________________________________________________________________________________
# Decoder1 (Decoder)              (None, 16, 16, 512)  9444864     Encoding[0][0]
#                                                                  Encoder4[0][0]
# __________________________________________________________________________________________________
# Decoder2 (Decoder)              (None, 32, 32, 256)  2953984     Decoder1[0][0]
#                                                                  Encoder3[0][0]
# __________________________________________________________________________________________________
# Decoder3 (Decoder)              (None, 64, 64, 128)  739712      Decoder2[0][0]
#                                                                  Encoder2[0][0]
# __________________________________________________________________________________________________
# Decoder4 (Decoder)              (None, 128, 128, 64) 185536      Decoder3[0][0]
#                                                                  Encoder1[0][0]
# __________________________________________________________________________________________________
# Segmentator (Conv2D)            (None, 128, 128, 3)  1731        Decoder4[0][0]
# ==================================================================================================
# Total params: 22,734,671
# Trainable params: 22,726,089
# Non-trainable params: 8,582
# __________________________________________________________________________________________________

# %%
history = model.fit(
                    train_images, train_fuse,
                    validation_split=0.1,
                    epochs=50,
                    batch_size=BATCH_SIZE,
                    steps_per_epoch=SPE,
                    callbacks=cbs
)
# Out:
# Epoch 1/50
# 37/37 [==============================] - 13s 277ms/step - loss: 0.6843 - accuracy: 0.4834 - val_loss: 0.8232 - val_accuracy: 0.5670
# Epoch 2/50
# 37/37 [==============================] - 10s 267ms/step - loss: 0.6077 - accuracy: 0.5727 - val_loss: 0.6418 - val_accuracy: 0.5577
# Epoch 3/50
# 37/37 [==============================] - 10s 269ms/step - loss: 0.5836 - accuracy: 0.6530 - val_loss: 0.6256 - val_accuracy: 0.6025
# Epoch 4/50
# 18/37 [=============>................] - ETA: 5s - loss: 0.5818 - accuracy: 0.6488
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# /tmp/ipykernel_791/1474641184.py in <module>
# ----> 1 history = model.fit(
#       2                     train_images, train_fuse,
#       3                     validation_split=0.1,
#       4                     epochs=50,
#       5                     batch_size=BATCH_SIZE,
#
# /opt/conda/lib/python3.9/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1182                 _r=1):
#    1183               callbacks.on_train_batch_begin(step)
# -> 1184               tmp_logs = self.train_function(iterator)
#    1185               if data_handler.should_sync:
#    1186                 context.async_wait()
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     883
#     884       with OptionalXlaContext(self._jit_compile):
# --> 885         result = self._call(*args, **kwds)
#     886
#     887       new_tracing_count = self.experimental_get_tracing_count()
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     915       # In this case we have created variables on the first call, so we run the
#     916       # defunned version which is guaranteed to never create variables.
# --> 917       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     918     elif self._stateful_fn is not None:
#     919       # Release the lock early so that multiple threads can perform the call
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3037       (graph_function,
#    3038        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3039     return graph_function._call_flat(
#    3040         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3041
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1961         and executing_eagerly):
#    1962       # No tape is watching; skip to running the function.
# -> 1963       return self._build_call_outputs(self._inference_function.call(
#    1964           ctx, args, cancellation_manager=cancellation_manager))
#    1965     forward_backward = self._select_forward_and_backward_functions(
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     589       with _InterpolateFunctionError(self):
#     590         if cancellation_manager is None:
# --> 591           outputs = execute.execute(
#     592               str(self.signature.name),
#     593               num_outputs=self._num_outputs,
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# ResourceExhaustedError:  OOM when allocating tensor with shape[16,64,128,128] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[node gradient_tape/UNet/Segmentator/Conv2D/Conv2DBackpropInput (defined at tmp/ipykernel_791/1474641184.py:1) ]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_train_function_15881]
#
# Function call stack:
# train_function

# %%
import matplotlib.pyplot as plt

# 손실 그래프
epochs = range(2, len(history.history["loss"]) + 1)
loss = history.history["loss"][1:] # 1의 손실 함수가 너무 커서 제외
val_loss = history.history["val_loss"][1:]

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 2)
plt.plot(epochs, loss, "b", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss", color = 'red')
plt.title("Training and validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

# 정확도 그래프
acc = history.history["accuracy"][1:]
val_acc = history.history["val_accuracy"][1:]

plt.subplot(1, 2, 1)
plt.plot(epochs, acc, "b", label="Training accuracy")
plt.plot(epochs, val_acc, "b", label="Validation accuracy", color = 'red')
plt.title("Training and validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()

plt.show()

# %%
# 테스트 데이터로 모델 평가
test_loss, test_accuracy = model.evaluate(test_images, test_fuse)

# 평가 결과 출력
print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)

# %%
# 이미지 데이터의 형태 확인
print(test_images.shape)  # (40, 128, 128, 3)

# 모델을 사용하여 테스트 이미지에 대한 예측 생성
pred = model.predict(test_images)

# 첫 번째 이미지 선택하여 출력
plt.figure(figsize=(20, 10))
plt.subplot(1, 3, 1); plt.imshow(test_images[0]); plt.title('Input Image', fontsize=20)
plt.subplot(1, 3, 2); plt.imshow(pred[0]); plt.title('Predicted Image', fontsize=20)
plt.subplot(1, 3, 3); plt.imshow(test_fuse[0]); plt.title('Fuse Image', fontsize=20)
plt.show()

# %% [markdown]
# GPU 메모리 부족으로 끝까지 돌려보지 못했다.
#
# 배치 크기 줄이거나 모델 크기를 줄여서 다시 시도해봐야겠다.
