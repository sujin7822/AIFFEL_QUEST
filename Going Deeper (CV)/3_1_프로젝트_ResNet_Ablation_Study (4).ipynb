# %%
import tensorflow as tf
import numpy as np

print(tf.__version__)
print(np.__version__)
# Out:
# 2.14.0
# 1.23.5

# %% [markdown]
# ###  Ablation Study 실습 (1) cats_vs_dogs  데이터셋 준비하기

# %% [markdown]
# **1) cats_vs_dogs**

# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

import tensorflow_datasets as tfds

# %%
# Tensorflow가 활용할 GPU가 장착되어 있는지 확인해 봅니다.
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import tensorflow as tf
import tensorflow_datasets as tfds

# setattr(tfds.image_classification.cats_vs_dogs, '_URL',"https://download.microsoft.com/download/3/E/1/3E1C3F21-ECDB-4869-8368-6DEBA77B919F/kagglecatsanddogs_5340.zip")


(ds_train, ds_test), ds_info = tfds.load(
    'cats_vs_dogs',
    split=['train[:80%]', 'train[80%:]'],
    as_supervised=True,
    shuffle_files=True,
    with_info=True,
)
# Out:
# Downloading and preparing dataset 786.68 MiB (download: 786.68 MiB, generated: Unknown size, total: 786.68 MiB) to /root/tensorflow_datasets/cats_vs_dogs/4.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Generating splits...:   0%|          | 0/1 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/23262 [00:00<?, ? examples/s]
# WARNING:absl:1738 images were corrupted and were skipped
# Shuffling /root/tensorflow_datasets/cats_vs_dogs/4.0.0.incompleteLVRA36/cats_vs_dogs-train.tfrecord*...:   0%|…
# Dataset cats_vs_dogs downloaded and prepared to /root/tensorflow_datasets/cats_vs_dogs/4.0.0. Subsequent calls will reuse this data.

# %%
print(ds_info.features)
# Out:
# FeaturesDict({
#     'image': Image(shape=(None, None, 3), dtype=uint8),
#     'image/filename': Text(shape=(), dtype=string),
#     'label': ClassLabel(shape=(), dtype=int64, num_classes=2),
# })

# %%
# 데이터의 개수도 확인해 봅시다.
print(tf.data.experimental.cardinality(ds_train))
print(tf.data.experimental.cardinality(ds_test))
# Out:
# tf.Tensor(18610, shape=(), dtype=int64)
# tf.Tensor(4652, shape=(), dtype=int64)

# %%
ds_info.features["label"].num_classes
# Out:
# 2

# %%
ds_info.features["label"].names
# Out:
# ['cat', 'dog']

# %%
fig = tfds.show_examples(ds_train, ds_info)

# %%
fig = tfds.show_examples(ds_test, ds_info)

# %% [markdown]
# **2) Input Normalization**

# %%
def normalize_and_resize_img(image, label):
    """Normalizes images: `uint8` -> `float32`."""
    image = tf.image.resize(image, (224,224))
    image = tf.cast(image, tf.float32) / 255.
    return image, label

# %%
def apply_normalize_on_dataset(ds, is_test=False, batch_size=16):
    ds = ds.map(
        normalize_and_resize_img,
        num_parallel_calls=1
    )
    ds = ds.batch(batch_size)
    if not is_test:
        ds = ds.repeat()
        ds = ds.shuffle(200)
    #ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
    return ds

# %% [markdown]
# ### Ablation Study 실습 (2) 블록 구성하기

# %% [markdown]
# 최근 나오는 일반적인 딥러닝 모델에서 이렇게 주요 구조를 모듈화 시켜 조금씩 바꾸어 쓸 수 있는 단위를 **블록(block)** 이라고 부른다. **레이어(layer)** 는 기본적으로 텐서플로우(TensorFlow), 케라스(Keras), 파이토치(PyTorch) 등에서 기본적으로 제공하는 단위이다. 우리는 여기서 한 단계 위인 "블록"을 단위로 모델을 만들 수 있어야 한다.
#
# **ResNet**을 보면 ResNet-18, 34, 50, 101, 152로 다섯 가지 네트워크
#
# 각 네트워크를 하나씩 구현하는 방법도 있지만 매우 수고스럽고 변경사항이 생기면 모두 고쳐줘야 하는 불편함이 생기게 된다. 따라서 이후 실습에서 우리는 ResNet의 기본 구조인 블록을 먼저 구현하자.

# %% [markdown]
# **ResNet 기본 블록 만들기**

# %% [markdown]
# block_num은 레이어의 이름을 붙여주기 위해서 추가되었고 input_shape는 summary를 출력하기 위해서 넣어주었다.

# %%
# conv하나 -> BatchNormalization -> Activation을 하나의 블록으로 묶고
def conv_block(input_layer,
               channel,
               kernel_size,
               strides=1,
               activation='relu'):

    x = keras.layers.Conv2D(filters=channel,
                            kernel_size=kernel_size,
                            kernel_initializer='he_normal',
                            kernel_regularizer=keras.regularizers.l2(1e-4),
                            padding='same',
                            strides=strides
                           )(input_layer)

    x = keras.layers.BatchNormalization()(x)

    if activation:
        x = keras.layers.Activation(activation)(x)

    return x

# %%
#위의 블록들을 ResNet-34의 경우는 2개를 묶어서 하나의 resnet블록으로 만들어주고,
# ResNet-50의 경우는 3개를 묶어서 하나의 resnet블록을 만들어준다.
def build_resnet_block(input_layer,
                       num_cnn=3,
                       channel=64,
                       block_num=0,
                       is_50=True):

    x = input_layer

    # ResNet-50
    if is_50:
        for i in range(num_cnn):
            if i == 0:
                shortcut = conv_block(x, channel*4, (1,1), strides=2, activation=None)
                x = conv_block(x, channel, (1,1), strides=2)
                x = conv_block(x, channel, (3,3))
                x = conv_block(x, channel*4, (1,1), activation=None) # 마지막은 relu
            else:
                shortcut = x
                x = conv_block(x, channel, (1,1))
                x = conv_block(x, channel, (3,3))
                x = conv_block(x, channel*4, (1,1), activation=None)

            x = keras.layers.Add()([x, shortcut])
            x = keras.layers.Activation('relu')(x)

    # ResNet-34
    else:
        for i in range(num_cnn):
            if block_num > 0 and i == 0:
                shortcut = conv_block(x, channel, (1,1), strides=2, activation=None)
                x = conv_block(x, channel, (3,3), strides=2)
                x = conv_block(x, channel, (3,3), activation=None)
            else:
                shortcut = x
                x = conv_block(x, channel, (3,3))
                x = conv_block(x, channel, (3,3), activation=None)

            x = keras.layers.Add()([x, shortcut])
            x = keras.layers.Activation('relu')(x)


    return x

# %%
def build_resnet(input_shape=(32,32,3),
                 num_cnn_list=[3,4,6,3],
                 channel_list=[64,128,256,512],
                 num_classes=2,
                 is_50=True,
                 activation='softmax',
                 name='ResNet_50'):

    assert len(num_cnn_list) == len(channel_list) # 모델을 만들기 전에 config list들이 같은 길이인지 확인합니다.

    input_layer = keras.layers.Input(shape=input_shape)  # input layer를 만들어둡니다.

    # first layer
    x = conv_block(input_layer, 64, (7,7), strides=2)
    x = keras.layers.MaxPool2D(pool_size=(2,2), strides=2)(x)

    # config list들의 길이만큼 반복해서 Residual block 블록을 생성합니다.
    for block_num, (num_cnn, channel) in enumerate(zip(num_cnn_list, channel_list)):
        x = build_resnet_block(x,
                               num_cnn=num_cnn,
                               channel=channel,
                               block_num=block_num,
                               is_50=is_50)
    x = keras.layers.GlobalAveragePooling2D()(x)
    x = keras.layers.Dense(num_classes,
                           activation=activation,
                           kernel_initializer='he_normal'
                          )(x)

    model = keras.Model(inputs=input_layer, outputs=x, name=name)

    return model

# %% [markdown]
# ### Ablation Study 실습 (3) ResNet Complete Model

# %% [markdown]
# 이제 기본적인 블록을 만들 수 있는 함수를 만들었으니 이를 합쳐서 전체 모델을 만들 수 있는 함수를 만들어보자.

# %% [markdown]
# **1) ResNet-34**

# %% [markdown]
# 먼저 작은 네트워크인 ResNet-34을 먼저 만들어 보자.
#
# 블록 내의 CNN 레이어 수와 채널 수는 블록마다 달라진다. 이는 ResNet-34과 ResNet-50에 따라서 같이 변화되므로 함수에 전달되어야 한다.

# %%
resnet_34 = build_resnet(input_shape=(224,224,3), is_50=False, activation='relu', name='ResNet_34')
resnet_34.summary()
# Out:
# Model: "ResNet_34"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 112, 112, 64)         9472      ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 112, 112, 64)         256       ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 112, 112, 64)         0         ['batch_normalization[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 56, 56, 64)           0         ['activation[0][0]']
#  D)
#
#  conv2d_1 (Conv2D)           (None, 56, 56, 64)           36928     ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (Bat  (None, 56, 56, 64)           256       ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 56, 56, 64)           0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 64)           36928     ['activation_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 56, 56, 64)           256       ['conv2d_2[0][0]']
#  chNormalization)
#
#  add (Add)                   (None, 56, 56, 64)           0         ['batch_normalization_2[0][0]'
#                                                                     , 'max_pooling2d[0][0]']
#
#  activation_2 (Activation)   (None, 56, 56, 64)           0         ['add[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 56, 56, 64)           36928     ['activation_2[0][0]']
#
#  batch_normalization_3 (Bat  (None, 56, 56, 64)           256       ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 56, 56, 64)           0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_4 (Conv2D)           (None, 56, 56, 64)           36928     ['activation_3[0][0]']
#
#  batch_normalization_4 (Bat  (None, 56, 56, 64)           256       ['conv2d_4[0][0]']
#  chNormalization)
#
#  add_1 (Add)                 (None, 56, 56, 64)           0         ['batch_normalization_4[0][0]'
#                                                                     , 'activation_2[0][0]']
#
#  activation_4 (Activation)   (None, 56, 56, 64)           0         ['add_1[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 56, 56, 64)           36928     ['activation_4[0][0]']
#
#  batch_normalization_5 (Bat  (None, 56, 56, 64)           256       ['conv2d_5[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 56, 56, 64)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 56, 56, 64)           36928     ['activation_5[0][0]']
#
#  batch_normalization_6 (Bat  (None, 56, 56, 64)           256       ['conv2d_6[0][0]']
#  chNormalization)
#
#  add_2 (Add)                 (None, 56, 56, 64)           0         ['batch_normalization_6[0][0]'
#                                                                     , 'activation_4[0][0]']
#
#  activation_6 (Activation)   (None, 56, 56, 64)           0         ['add_2[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 28, 28, 128)          73856     ['activation_6[0][0]']
#
#  batch_normalization_8 (Bat  (None, 28, 28, 128)          512       ['conv2d_8[0][0]']
#  chNormalization)
#
#  activation_7 (Activation)   (None, 28, 28, 128)          0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_9 (Conv2D)           (None, 28, 28, 128)          147584    ['activation_7[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 28, 28, 128)          8320      ['activation_6[0][0]']
#
#  batch_normalization_9 (Bat  (None, 28, 28, 128)          512       ['conv2d_9[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 28, 28, 128)          512       ['conv2d_7[0][0]']
#  chNormalization)
#
#  add_3 (Add)                 (None, 28, 28, 128)          0         ['batch_normalization_9[0][0]'
#                                                                     , 'batch_normalization_7[0][0]
#                                                                     ']
#
#  activation_8 (Activation)   (None, 28, 28, 128)          0         ['add_3[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 28, 28, 128)          147584    ['activation_8[0][0]']
#
#  batch_normalization_10 (Ba  (None, 28, 28, 128)          512       ['conv2d_10[0][0]']
#  tchNormalization)
#
#  activation_9 (Activation)   (None, 28, 28, 128)          0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  conv2d_11 (Conv2D)          (None, 28, 28, 128)          147584    ['activation_9[0][0]']
#
#  batch_normalization_11 (Ba  (None, 28, 28, 128)          512       ['conv2d_11[0][0]']
#  tchNormalization)
#
#  add_4 (Add)                 (None, 28, 28, 128)          0         ['batch_normalization_11[0][0]
#                                                                     ',
#                                                                      'activation_8[0][0]']
#
#  activation_10 (Activation)  (None, 28, 28, 128)          0         ['add_4[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 28, 28, 128)          147584    ['activation_10[0][0]']
#
#  batch_normalization_12 (Ba  (None, 28, 28, 128)          512       ['conv2d_12[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 28, 28, 128)          0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  conv2d_13 (Conv2D)          (None, 28, 28, 128)          147584    ['activation_11[0][0]']
#
#  batch_normalization_13 (Ba  (None, 28, 28, 128)          512       ['conv2d_13[0][0]']
#  tchNormalization)
#
#  add_5 (Add)                 (None, 28, 28, 128)          0         ['batch_normalization_13[0][0]
#                                                                     ',
#                                                                      'activation_10[0][0]']
#
#  activation_12 (Activation)  (None, 28, 28, 128)          0         ['add_5[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 28, 28, 128)          147584    ['activation_12[0][0]']
#
#  batch_normalization_14 (Ba  (None, 28, 28, 128)          512       ['conv2d_14[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 28, 28, 128)          0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  conv2d_15 (Conv2D)          (None, 28, 28, 128)          147584    ['activation_13[0][0]']
#
#  batch_normalization_15 (Ba  (None, 28, 28, 128)          512       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  add_6 (Add)                 (None, 28, 28, 128)          0         ['batch_normalization_15[0][0]
#                                                                     ',
#                                                                      'activation_12[0][0]']
#
#  activation_14 (Activation)  (None, 28, 28, 128)          0         ['add_6[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 14, 14, 256)          295168    ['activation_14[0][0]']
#
#  batch_normalization_17 (Ba  (None, 14, 14, 256)          1024      ['conv2d_17[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 14, 14, 256)          0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  conv2d_18 (Conv2D)          (None, 14, 14, 256)          590080    ['activation_15[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 14, 14, 256)          33024     ['activation_14[0][0]']
#
#  batch_normalization_18 (Ba  (None, 14, 14, 256)          1024      ['conv2d_18[0][0]']
#  tchNormalization)
#
#  batch_normalization_16 (Ba  (None, 14, 14, 256)          1024      ['conv2d_16[0][0]']
#  tchNormalization)
#
#  add_7 (Add)                 (None, 14, 14, 256)          0         ['batch_normalization_18[0][0]
#                                                                     ',
#                                                                      'batch_normalization_16[0][0]
#                                                                     ']
#
#  activation_16 (Activation)  (None, 14, 14, 256)          0         ['add_7[0][0]']
#
#  conv2d_19 (Conv2D)          (None, 14, 14, 256)          590080    ['activation_16[0][0]']
#
#  batch_normalization_19 (Ba  (None, 14, 14, 256)          1024      ['conv2d_19[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 14, 14, 256)          0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  conv2d_20 (Conv2D)          (None, 14, 14, 256)          590080    ['activation_17[0][0]']
#
#  batch_normalization_20 (Ba  (None, 14, 14, 256)          1024      ['conv2d_20[0][0]']
#  tchNormalization)
#
#  add_8 (Add)                 (None, 14, 14, 256)          0         ['batch_normalization_20[0][0]
#                                                                     ',
#                                                                      'activation_16[0][0]']
#
#  activation_18 (Activation)  (None, 14, 14, 256)          0         ['add_8[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 14, 14, 256)          590080    ['activation_18[0][0]']
#
#  batch_normalization_21 (Ba  (None, 14, 14, 256)          1024      ['conv2d_21[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 14, 14, 256)          0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  conv2d_22 (Conv2D)          (None, 14, 14, 256)          590080    ['activation_19[0][0]']
#
#  batch_normalization_22 (Ba  (None, 14, 14, 256)          1024      ['conv2d_22[0][0]']
#  tchNormalization)
#
#  add_9 (Add)                 (None, 14, 14, 256)          0         ['batch_normalization_22[0][0]
#                                                                     ',
#                                                                      'activation_18[0][0]']
#
#  activation_20 (Activation)  (None, 14, 14, 256)          0         ['add_9[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 14, 14, 256)          590080    ['activation_20[0][0]']
#
#  batch_normalization_23 (Ba  (None, 14, 14, 256)          1024      ['conv2d_23[0][0]']
#  tchNormalization)
#
#  activation_21 (Activation)  (None, 14, 14, 256)          0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  conv2d_24 (Conv2D)          (None, 14, 14, 256)          590080    ['activation_21[0][0]']
#
#  batch_normalization_24 (Ba  (None, 14, 14, 256)          1024      ['conv2d_24[0][0]']
#  tchNormalization)
#
#  add_10 (Add)                (None, 14, 14, 256)          0         ['batch_normalization_24[0][0]
#                                                                     ',
#                                                                      'activation_20[0][0]']
#
#  activation_22 (Activation)  (None, 14, 14, 256)          0         ['add_10[0][0]']
#
#  conv2d_25 (Conv2D)          (None, 14, 14, 256)          590080    ['activation_22[0][0]']
#
#  batch_normalization_25 (Ba  (None, 14, 14, 256)          1024      ['conv2d_25[0][0]']
#  tchNormalization)
#
#  activation_23 (Activation)  (None, 14, 14, 256)          0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  conv2d_26 (Conv2D)          (None, 14, 14, 256)          590080    ['activation_23[0][0]']
#
#  batch_normalization_26 (Ba  (None, 14, 14, 256)          1024      ['conv2d_26[0][0]']
#  tchNormalization)
#
#  add_11 (Add)                (None, 14, 14, 256)          0         ['batch_normalization_26[0][0]
#                                                                     ',
#                                                                      'activation_22[0][0]']
#
#  activation_24 (Activation)  (None, 14, 14, 256)          0         ['add_11[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 14, 14, 256)          590080    ['activation_24[0][0]']
#
#  batch_normalization_27 (Ba  (None, 14, 14, 256)          1024      ['conv2d_27[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 14, 14, 256)          0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  conv2d_28 (Conv2D)          (None, 14, 14, 256)          590080    ['activation_25[0][0]']
#
#  batch_normalization_28 (Ba  (None, 14, 14, 256)          1024      ['conv2d_28[0][0]']
#  tchNormalization)
#
#  add_12 (Add)                (None, 14, 14, 256)          0         ['batch_normalization_28[0][0]
#                                                                     ',
#                                                                      'activation_24[0][0]']
#
#  activation_26 (Activation)  (None, 14, 14, 256)          0         ['add_12[0][0]']
#
#  conv2d_30 (Conv2D)          (None, 7, 7, 512)            1180160   ['activation_26[0][0]']
#
#  batch_normalization_30 (Ba  (None, 7, 7, 512)            2048      ['conv2d_30[0][0]']
#  tchNormalization)
#
#  activation_27 (Activation)  (None, 7, 7, 512)            0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  conv2d_31 (Conv2D)          (None, 7, 7, 512)            2359808   ['activation_27[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 7, 7, 512)            131584    ['activation_26[0][0]']
#
#  batch_normalization_31 (Ba  (None, 7, 7, 512)            2048      ['conv2d_31[0][0]']
#  tchNormalization)
#
#  batch_normalization_29 (Ba  (None, 7, 7, 512)            2048      ['conv2d_29[0][0]']
#  tchNormalization)
#
#  add_13 (Add)                (None, 7, 7, 512)            0         ['batch_normalization_31[0][0]
#                                                                     ',
#                                                                      'batch_normalization_29[0][0]
#                                                                     ']
#
#  activation_28 (Activation)  (None, 7, 7, 512)            0         ['add_13[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 7, 7, 512)            2359808   ['activation_28[0][0]']
#
#  batch_normalization_32 (Ba  (None, 7, 7, 512)            2048      ['conv2d_32[0][0]']
#  tchNormalization)
#
#  activation_29 (Activation)  (None, 7, 7, 512)            0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  conv2d_33 (Conv2D)          (None, 7, 7, 512)            2359808   ['activation_29[0][0]']
#
#  batch_normalization_33 (Ba  (None, 7, 7, 512)            2048      ['conv2d_33[0][0]']
#  tchNormalization)
#
#  add_14 (Add)                (None, 7, 7, 512)            0         ['batch_normalization_33[0][0]
#                                                                     ',
#                                                                      'activation_28[0][0]']
#
#  activation_30 (Activation)  (None, 7, 7, 512)            0         ['add_14[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 7, 7, 512)            2359808   ['activation_30[0][0]']
#
#  batch_normalization_34 (Ba  (None, 7, 7, 512)            2048      ['conv2d_34[0][0]']
#  tchNormalization)
#
#  activation_31 (Activation)  (None, 7, 7, 512)            0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  conv2d_35 (Conv2D)          (None, 7, 7, 512)            2359808   ['activation_31[0][0]']
#
#  batch_normalization_35 (Ba  (None, 7, 7, 512)            2048      ['conv2d_35[0][0]']
#  tchNormalization)
#
#  add_15 (Add)                (None, 7, 7, 512)            0         ['batch_normalization_35[0][0]
#                                                                     ',
#                                                                      'activation_30[0][0]']
#
#  activation_32 (Activation)  (None, 7, 7, 512)            0         ['add_15[0][0]']
#
#  global_average_pooling2d (  (None, 512)                  0         ['activation_32[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 2)                    1026      ['global_average_pooling2d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 21311234 (81.30 MB)
# Trainable params: 21294210 (81.23 MB)
# Non-trainable params: 17024 (66.50 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# **2) ResNet-50**

# %%
resnet_50 = build_resnet(input_shape=(224,224,3), is_50=True, activation='relu', name='ResNet_50')
resnet_50.summary()
# Out:
# Model: "ResNet_50"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv2d_36 (Conv2D)          (None, 112, 112, 64)         9472      ['input_2[0][0]']
#
#  batch_normalization_36 (Ba  (None, 112, 112, 64)         256       ['conv2d_36[0][0]']
#  tchNormalization)
#
#  activation_33 (Activation)  (None, 112, 112, 64)         0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  max_pooling2d_1 (MaxPoolin  (None, 56, 56, 64)           0         ['activation_33[0][0]']
#  g2D)
#
#  conv2d_38 (Conv2D)          (None, 28, 28, 64)           4160      ['max_pooling2d_1[0][0]']
#
#  batch_normalization_38 (Ba  (None, 28, 28, 64)           256       ['conv2d_38[0][0]']
#  tchNormalization)
#
#  activation_34 (Activation)  (None, 28, 28, 64)           0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  conv2d_39 (Conv2D)          (None, 28, 28, 64)           36928     ['activation_34[0][0]']
#
#  batch_normalization_39 (Ba  (None, 28, 28, 64)           256       ['conv2d_39[0][0]']
#  tchNormalization)
#
#  activation_35 (Activation)  (None, 28, 28, 64)           0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  conv2d_40 (Conv2D)          (None, 28, 28, 256)          16640     ['activation_35[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 28, 28, 256)          16640     ['max_pooling2d_1[0][0]']
#
#  batch_normalization_40 (Ba  (None, 28, 28, 256)          1024      ['conv2d_40[0][0]']
#  tchNormalization)
#
#  batch_normalization_37 (Ba  (None, 28, 28, 256)          1024      ['conv2d_37[0][0]']
#  tchNormalization)
#
#  add_16 (Add)                (None, 28, 28, 256)          0         ['batch_normalization_40[0][0]
#                                                                     ',
#                                                                      'batch_normalization_37[0][0]
#                                                                     ']
#
#  activation_36 (Activation)  (None, 28, 28, 256)          0         ['add_16[0][0]']
#
#  conv2d_41 (Conv2D)          (None, 28, 28, 64)           16448     ['activation_36[0][0]']
#
#  batch_normalization_41 (Ba  (None, 28, 28, 64)           256       ['conv2d_41[0][0]']
#  tchNormalization)
#
#  activation_37 (Activation)  (None, 28, 28, 64)           0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 28, 28, 64)           36928     ['activation_37[0][0]']
#
#  batch_normalization_42 (Ba  (None, 28, 28, 64)           256       ['conv2d_42[0][0]']
#  tchNormalization)
#
#  activation_38 (Activation)  (None, 28, 28, 64)           0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  conv2d_43 (Conv2D)          (None, 28, 28, 256)          16640     ['activation_38[0][0]']
#
#  batch_normalization_43 (Ba  (None, 28, 28, 256)          1024      ['conv2d_43[0][0]']
#  tchNormalization)
#
#  add_17 (Add)                (None, 28, 28, 256)          0         ['batch_normalization_43[0][0]
#                                                                     ',
#                                                                      'activation_36[0][0]']
#
#  activation_39 (Activation)  (None, 28, 28, 256)          0         ['add_17[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 28, 28, 64)           16448     ['activation_39[0][0]']
#
#  batch_normalization_44 (Ba  (None, 28, 28, 64)           256       ['conv2d_44[0][0]']
#  tchNormalization)
#
#  activation_40 (Activation)  (None, 28, 28, 64)           0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  conv2d_45 (Conv2D)          (None, 28, 28, 64)           36928     ['activation_40[0][0]']
#
#  batch_normalization_45 (Ba  (None, 28, 28, 64)           256       ['conv2d_45[0][0]']
#  tchNormalization)
#
#  activation_41 (Activation)  (None, 28, 28, 64)           0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  conv2d_46 (Conv2D)          (None, 28, 28, 256)          16640     ['activation_41[0][0]']
#
#  batch_normalization_46 (Ba  (None, 28, 28, 256)          1024      ['conv2d_46[0][0]']
#  tchNormalization)
#
#  add_18 (Add)                (None, 28, 28, 256)          0         ['batch_normalization_46[0][0]
#                                                                     ',
#                                                                      'activation_39[0][0]']
#
#  activation_42 (Activation)  (None, 28, 28, 256)          0         ['add_18[0][0]']
#
#  conv2d_48 (Conv2D)          (None, 14, 14, 128)          32896     ['activation_42[0][0]']
#
#  batch_normalization_48 (Ba  (None, 14, 14, 128)          512       ['conv2d_48[0][0]']
#  tchNormalization)
#
#  activation_43 (Activation)  (None, 14, 14, 128)          0         ['batch_normalization_48[0][0]
#                                                                     ']
#
#  conv2d_49 (Conv2D)          (None, 14, 14, 128)          147584    ['activation_43[0][0]']
#
#  batch_normalization_49 (Ba  (None, 14, 14, 128)          512       ['conv2d_49[0][0]']
#  tchNormalization)
#
#  activation_44 (Activation)  (None, 14, 14, 128)          0         ['batch_normalization_49[0][0]
#                                                                     ']
#
#  conv2d_50 (Conv2D)          (None, 14, 14, 512)          66048     ['activation_44[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 14, 14, 512)          131584    ['activation_42[0][0]']
#
#  batch_normalization_50 (Ba  (None, 14, 14, 512)          2048      ['conv2d_50[0][0]']
#  tchNormalization)
#
#  batch_normalization_47 (Ba  (None, 14, 14, 512)          2048      ['conv2d_47[0][0]']
#  tchNormalization)
#
#  add_19 (Add)                (None, 14, 14, 512)          0         ['batch_normalization_50[0][0]
#                                                                     ',
#                                                                      'batch_normalization_47[0][0]
#                                                                     ']
#
#  activation_45 (Activation)  (None, 14, 14, 512)          0         ['add_19[0][0]']
#
#  conv2d_51 (Conv2D)          (None, 14, 14, 128)          65664     ['activation_45[0][0]']
#
#  batch_normalization_51 (Ba  (None, 14, 14, 128)          512       ['conv2d_51[0][0]']
#  tchNormalization)
#
#  activation_46 (Activation)  (None, 14, 14, 128)          0         ['batch_normalization_51[0][0]
#                                                                     ']
#
#  conv2d_52 (Conv2D)          (None, 14, 14, 128)          147584    ['activation_46[0][0]']
#
#  batch_normalization_52 (Ba  (None, 14, 14, 128)          512       ['conv2d_52[0][0]']
#  tchNormalization)
#
#  activation_47 (Activation)  (None, 14, 14, 128)          0         ['batch_normalization_52[0][0]
#                                                                     ']
#
#  conv2d_53 (Conv2D)          (None, 14, 14, 512)          66048     ['activation_47[0][0]']
#
#  batch_normalization_53 (Ba  (None, 14, 14, 512)          2048      ['conv2d_53[0][0]']
#  tchNormalization)
#
#  add_20 (Add)                (None, 14, 14, 512)          0         ['batch_normalization_53[0][0]
#                                                                     ',
#                                                                      'activation_45[0][0]']
#
#  activation_48 (Activation)  (None, 14, 14, 512)          0         ['add_20[0][0]']
#
#  conv2d_54 (Conv2D)          (None, 14, 14, 128)          65664     ['activation_48[0][0]']
#
#  batch_normalization_54 (Ba  (None, 14, 14, 128)          512       ['conv2d_54[0][0]']
#  tchNormalization)
#
#  activation_49 (Activation)  (None, 14, 14, 128)          0         ['batch_normalization_54[0][0]
#                                                                     ']
#
#  conv2d_55 (Conv2D)          (None, 14, 14, 128)          147584    ['activation_49[0][0]']
#
#  batch_normalization_55 (Ba  (None, 14, 14, 128)          512       ['conv2d_55[0][0]']
#  tchNormalization)
#
#  activation_50 (Activation)  (None, 14, 14, 128)          0         ['batch_normalization_55[0][0]
#                                                                     ']
#
#  conv2d_56 (Conv2D)          (None, 14, 14, 512)          66048     ['activation_50[0][0]']
#
#  batch_normalization_56 (Ba  (None, 14, 14, 512)          2048      ['conv2d_56[0][0]']
#  tchNormalization)
#
#  add_21 (Add)                (None, 14, 14, 512)          0         ['batch_normalization_56[0][0]
#                                                                     ',
#                                                                      'activation_48[0][0]']
#
#  activation_51 (Activation)  (None, 14, 14, 512)          0         ['add_21[0][0]']
#
#  conv2d_57 (Conv2D)          (None, 14, 14, 128)          65664     ['activation_51[0][0]']
#
#  batch_normalization_57 (Ba  (None, 14, 14, 128)          512       ['conv2d_57[0][0]']
#  tchNormalization)
#
#  activation_52 (Activation)  (None, 14, 14, 128)          0         ['batch_normalization_57[0][0]
#                                                                     ']
#
#  conv2d_58 (Conv2D)          (None, 14, 14, 128)          147584    ['activation_52[0][0]']
#
#  batch_normalization_58 (Ba  (None, 14, 14, 128)          512       ['conv2d_58[0][0]']
#  tchNormalization)
#
#  activation_53 (Activation)  (None, 14, 14, 128)          0         ['batch_normalization_58[0][0]
#                                                                     ']
#
#  conv2d_59 (Conv2D)          (None, 14, 14, 512)          66048     ['activation_53[0][0]']
#
#  batch_normalization_59 (Ba  (None, 14, 14, 512)          2048      ['conv2d_59[0][0]']
#  tchNormalization)
#
#  add_22 (Add)                (None, 14, 14, 512)          0         ['batch_normalization_59[0][0]
#                                                                     ',
#                                                                      'activation_51[0][0]']
#
#  activation_54 (Activation)  (None, 14, 14, 512)          0         ['add_22[0][0]']
#
#  conv2d_61 (Conv2D)          (None, 7, 7, 256)            131328    ['activation_54[0][0]']
#
#  batch_normalization_61 (Ba  (None, 7, 7, 256)            1024      ['conv2d_61[0][0]']
#  tchNormalization)
#
#  activation_55 (Activation)  (None, 7, 7, 256)            0         ['batch_normalization_61[0][0]
#                                                                     ']
#
#  conv2d_62 (Conv2D)          (None, 7, 7, 256)            590080    ['activation_55[0][0]']
#
#  batch_normalization_62 (Ba  (None, 7, 7, 256)            1024      ['conv2d_62[0][0]']
#  tchNormalization)
#
#  activation_56 (Activation)  (None, 7, 7, 256)            0         ['batch_normalization_62[0][0]
#                                                                     ']
#
#  conv2d_63 (Conv2D)          (None, 7, 7, 1024)           263168    ['activation_56[0][0]']
#
#  conv2d_60 (Conv2D)          (None, 7, 7, 1024)           525312    ['activation_54[0][0]']
#
#  batch_normalization_63 (Ba  (None, 7, 7, 1024)           4096      ['conv2d_63[0][0]']
#  tchNormalization)
#
#  batch_normalization_60 (Ba  (None, 7, 7, 1024)           4096      ['conv2d_60[0][0]']
#  tchNormalization)
#
#  add_23 (Add)                (None, 7, 7, 1024)           0         ['batch_normalization_63[0][0]
#                                                                     ',
#                                                                      'batch_normalization_60[0][0]
#                                                                     ']
#
#  activation_57 (Activation)  (None, 7, 7, 1024)           0         ['add_23[0][0]']
#
#  conv2d_64 (Conv2D)          (None, 7, 7, 256)            262400    ['activation_57[0][0]']
#
#  batch_normalization_64 (Ba  (None, 7, 7, 256)            1024      ['conv2d_64[0][0]']
#  tchNormalization)
#
#  activation_58 (Activation)  (None, 7, 7, 256)            0         ['batch_normalization_64[0][0]
#                                                                     ']
#
#  conv2d_65 (Conv2D)          (None, 7, 7, 256)            590080    ['activation_58[0][0]']
#
#  batch_normalization_65 (Ba  (None, 7, 7, 256)            1024      ['conv2d_65[0][0]']
#  tchNormalization)
#
#  activation_59 (Activation)  (None, 7, 7, 256)            0         ['batch_normalization_65[0][0]
#                                                                     ']
#
#  conv2d_66 (Conv2D)          (None, 7, 7, 1024)           263168    ['activation_59[0][0]']
#
#  batch_normalization_66 (Ba  (None, 7, 7, 1024)           4096      ['conv2d_66[0][0]']
#  tchNormalization)
#
#  add_24 (Add)                (None, 7, 7, 1024)           0         ['batch_normalization_66[0][0]
#                                                                     ',
#                                                                      'activation_57[0][0]']
#
#  activation_60 (Activation)  (None, 7, 7, 1024)           0         ['add_24[0][0]']
#
#  conv2d_67 (Conv2D)          (None, 7, 7, 256)            262400    ['activation_60[0][0]']
#
#  batch_normalization_67 (Ba  (None, 7, 7, 256)            1024      ['conv2d_67[0][0]']
#  tchNormalization)
#
#  activation_61 (Activation)  (None, 7, 7, 256)            0         ['batch_normalization_67[0][0]
#                                                                     ']
#
#  conv2d_68 (Conv2D)          (None, 7, 7, 256)            590080    ['activation_61[0][0]']
#
#  batch_normalization_68 (Ba  (None, 7, 7, 256)            1024      ['conv2d_68[0][0]']
#  tchNormalization)
#
#  activation_62 (Activation)  (None, 7, 7, 256)            0         ['batch_normalization_68[0][0]
#                                                                     ']
#
#  conv2d_69 (Conv2D)          (None, 7, 7, 1024)           263168    ['activation_62[0][0]']
#
#  batch_normalization_69 (Ba  (None, 7, 7, 1024)           4096      ['conv2d_69[0][0]']
#  tchNormalization)
#
#  add_25 (Add)                (None, 7, 7, 1024)           0         ['batch_normalization_69[0][0]
#                                                                     ',
#                                                                      'activation_60[0][0]']
#
#  activation_63 (Activation)  (None, 7, 7, 1024)           0         ['add_25[0][0]']
#
#  conv2d_70 (Conv2D)          (None, 7, 7, 256)            262400    ['activation_63[0][0]']
#
#  batch_normalization_70 (Ba  (None, 7, 7, 256)            1024      ['conv2d_70[0][0]']
#  tchNormalization)
#
#  activation_64 (Activation)  (None, 7, 7, 256)            0         ['batch_normalization_70[0][0]
#                                                                     ']
#
#  conv2d_71 (Conv2D)          (None, 7, 7, 256)            590080    ['activation_64[0][0]']
#
#  batch_normalization_71 (Ba  (None, 7, 7, 256)            1024      ['conv2d_71[0][0]']
#  tchNormalization)
#
#  activation_65 (Activation)  (None, 7, 7, 256)            0         ['batch_normalization_71[0][0]
#                                                                     ']
#
#  conv2d_72 (Conv2D)          (None, 7, 7, 1024)           263168    ['activation_65[0][0]']
#
#  batch_normalization_72 (Ba  (None, 7, 7, 1024)           4096      ['conv2d_72[0][0]']
#  tchNormalization)
#
#  add_26 (Add)                (None, 7, 7, 1024)           0         ['batch_normalization_72[0][0]
#                                                                     ',
#                                                                      'activation_63[0][0]']
#
#  activation_66 (Activation)  (None, 7, 7, 1024)           0         ['add_26[0][0]']
#
#  conv2d_73 (Conv2D)          (None, 7, 7, 256)            262400    ['activation_66[0][0]']
#
#  batch_normalization_73 (Ba  (None, 7, 7, 256)            1024      ['conv2d_73[0][0]']
#  tchNormalization)
#
#  activation_67 (Activation)  (None, 7, 7, 256)            0         ['batch_normalization_73[0][0]
#                                                                     ']
#
#  conv2d_74 (Conv2D)          (None, 7, 7, 256)            590080    ['activation_67[0][0]']
#
#  batch_normalization_74 (Ba  (None, 7, 7, 256)            1024      ['conv2d_74[0][0]']
#  tchNormalization)
#
#  activation_68 (Activation)  (None, 7, 7, 256)            0         ['batch_normalization_74[0][0]
#                                                                     ']
#
#  conv2d_75 (Conv2D)          (None, 7, 7, 1024)           263168    ['activation_68[0][0]']
#
#  batch_normalization_75 (Ba  (None, 7, 7, 1024)           4096      ['conv2d_75[0][0]']
#  tchNormalization)
#
#  add_27 (Add)                (None, 7, 7, 1024)           0         ['batch_normalization_75[0][0]
#                                                                     ',
#                                                                      'activation_66[0][0]']
#
#  activation_69 (Activation)  (None, 7, 7, 1024)           0         ['add_27[0][0]']
#
#  conv2d_76 (Conv2D)          (None, 7, 7, 256)            262400    ['activation_69[0][0]']
#
#  batch_normalization_76 (Ba  (None, 7, 7, 256)            1024      ['conv2d_76[0][0]']
#  tchNormalization)
#
#  activation_70 (Activation)  (None, 7, 7, 256)            0         ['batch_normalization_76[0][0]
#                                                                     ']
#
#  conv2d_77 (Conv2D)          (None, 7, 7, 256)            590080    ['activation_70[0][0]']
#
#  batch_normalization_77 (Ba  (None, 7, 7, 256)            1024      ['conv2d_77[0][0]']
#  tchNormalization)
#
#  activation_71 (Activation)  (None, 7, 7, 256)            0         ['batch_normalization_77[0][0]
#                                                                     ']
#
#  conv2d_78 (Conv2D)          (None, 7, 7, 1024)           263168    ['activation_71[0][0]']
#
#  batch_normalization_78 (Ba  (None, 7, 7, 1024)           4096      ['conv2d_78[0][0]']
#  tchNormalization)
#
#  add_28 (Add)                (None, 7, 7, 1024)           0         ['batch_normalization_78[0][0]
#                                                                     ',
#                                                                      'activation_69[0][0]']
#
#  activation_72 (Activation)  (None, 7, 7, 1024)           0         ['add_28[0][0]']
#
#  conv2d_80 (Conv2D)          (None, 4, 4, 512)            524800    ['activation_72[0][0]']
#
#  batch_normalization_80 (Ba  (None, 4, 4, 512)            2048      ['conv2d_80[0][0]']
#  tchNormalization)
#
#  activation_73 (Activation)  (None, 4, 4, 512)            0         ['batch_normalization_80[0][0]
#                                                                     ']
#
#  conv2d_81 (Conv2D)          (None, 4, 4, 512)            2359808   ['activation_73[0][0]']
#
#  batch_normalization_81 (Ba  (None, 4, 4, 512)            2048      ['conv2d_81[0][0]']
#  tchNormalization)
#
#  activation_74 (Activation)  (None, 4, 4, 512)            0         ['batch_normalization_81[0][0]
#                                                                     ']
#
#  conv2d_82 (Conv2D)          (None, 4, 4, 2048)           1050624   ['activation_74[0][0]']
#
#  conv2d_79 (Conv2D)          (None, 4, 4, 2048)           2099200   ['activation_72[0][0]']
#
#  batch_normalization_82 (Ba  (None, 4, 4, 2048)           8192      ['conv2d_82[0][0]']
#  tchNormalization)
#
#  batch_normalization_79 (Ba  (None, 4, 4, 2048)           8192      ['conv2d_79[0][0]']
#  tchNormalization)
#
#  add_29 (Add)                (None, 4, 4, 2048)           0         ['batch_normalization_82[0][0]
#                                                                     ',
#                                                                      'batch_normalization_79[0][0]
#                                                                     ']
#
#  activation_75 (Activation)  (None, 4, 4, 2048)           0         ['add_29[0][0]']
#
#  conv2d_83 (Conv2D)          (None, 4, 4, 512)            1049088   ['activation_75[0][0]']
#
#  batch_normalization_83 (Ba  (None, 4, 4, 512)            2048      ['conv2d_83[0][0]']
#  tchNormalization)
#
#  activation_76 (Activation)  (None, 4, 4, 512)            0         ['batch_normalization_83[0][0]
#                                                                     ']
#
#  conv2d_84 (Conv2D)          (None, 4, 4, 512)            2359808   ['activation_76[0][0]']
#
#  batch_normalization_84 (Ba  (None, 4, 4, 512)            2048      ['conv2d_84[0][0]']
#  tchNormalization)
#
#  activation_77 (Activation)  (None, 4, 4, 512)            0         ['batch_normalization_84[0][0]
#                                                                     ']
#
#  conv2d_85 (Conv2D)          (None, 4, 4, 2048)           1050624   ['activation_77[0][0]']
#
#  batch_normalization_85 (Ba  (None, 4, 4, 2048)           8192      ['conv2d_85[0][0]']
#  tchNormalization)
#
#  add_30 (Add)                (None, 4, 4, 2048)           0         ['batch_normalization_85[0][0]
#                                                                     ',
#                                                                      'activation_75[0][0]']
#
#  activation_78 (Activation)  (None, 4, 4, 2048)           0         ['add_30[0][0]']
#
#  conv2d_86 (Conv2D)          (None, 4, 4, 512)            1049088   ['activation_78[0][0]']
#
#  batch_normalization_86 (Ba  (None, 4, 4, 512)            2048      ['conv2d_86[0][0]']
#  tchNormalization)
#
#  activation_79 (Activation)  (None, 4, 4, 512)            0         ['batch_normalization_86[0][0]
#                                                                     ']
#
#  conv2d_87 (Conv2D)          (None, 4, 4, 512)            2359808   ['activation_79[0][0]']
#
#  batch_normalization_87 (Ba  (None, 4, 4, 512)            2048      ['conv2d_87[0][0]']
#  tchNormalization)
#
#  activation_80 (Activation)  (None, 4, 4, 512)            0         ['batch_normalization_87[0][0]
#                                                                     ']
#
#  conv2d_88 (Conv2D)          (None, 4, 4, 2048)           1050624   ['activation_80[0][0]']
#
#  batch_normalization_88 (Ba  (None, 4, 4, 2048)           8192      ['conv2d_88[0][0]']
#  tchNormalization)
#
#  add_31 (Add)                (None, 4, 4, 2048)           0         ['batch_normalization_88[0][0]
#                                                                     ',
#                                                                      'activation_78[0][0]']
#
#  activation_81 (Activation)  (None, 4, 4, 2048)           0         ['add_31[0][0]']
#
#  global_average_pooling2d_1  (None, 2048)                 0         ['activation_81[0][0]']
#   (GlobalAveragePooling2D)
#
#  dense_1 (Dense)             (None, 2)                    4098      ['global_average_pooling2d_1[0
#                                                                     ][0]']
#
# ==================================================================================================
# Total params: 23591810 (90.00 MB)
# Trainable params: 23538690 (89.79 MB)
# Non-trainable params: 53120 (207.50 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# **Ablation Study 실습 (4) 일반 네트워크(plain network) 만들기**

# %%
def build_plain_block(input_layer,
                      num_cnn=3,
                      channel=64,
                      block_num=0,
                      is_50=True):

    x = input_layer

    # plain-50
    if is_50:
        for i in range(num_cnn):
            if block_num > 0 and i == 0:
                x = conv_block(x, channel, (1,1), strides=2)
                x = conv_block(x, channel, (3,3))
                x = conv_block(x, channel*4, (1,1))
            else:
                x = conv_block(x, channel, (1,1))
                x = conv_block(x, channel, (3,3))
                x = conv_block(x, channel*4, (1,1))

    # plain-34
    else:
        for i in range(num_cnn):
            if block_num > 0 and i == 0:
                x = conv_block(x, channel, (3,3), strides=2)
                x = conv_block(x, channel, (3,3))
            else:
                x = conv_block(x, channel, (3,3))
                x = conv_block(x, channel, (3,3))

    return x

# %%
def build_plain(input_shape=(32,32,3),
                   num_cnn_list=[3,4,6,3],
                   channel_list=[64,128,256,512],
                   num_classes=2,
                   is_50=True,
                   activation='softmax',
                   name='Plain_50'):

    assert len(num_cnn_list) == len(channel_list)

    input_layer = keras.layers.Input(shape=input_shape)

    # first layer
    x = conv_block(input_layer, 64, (7,7), strides=2)
    x = keras.layers.MaxPool2D(pool_size=(2,2), strides=2)(x)

    # config list들의 길이만큼 반복해서 plain block 블록을 생성합니다.
    for block_num, (num_cnn, channel) in enumerate(zip(num_cnn_list, channel_list)):
        x = build_plain_block(x,
                              num_cnn=num_cnn,
                              channel=channel,
                              block_num=block_num,
                              is_50=is_50)


    x = keras.layers.GlobalAveragePooling2D()(x)
    x = keras.layers.Dense(num_classes,
                           activation=activation,
                           kernel_initializer='he_normal'
                          )(x)

    model = keras.Model(inputs=input_layer, outputs=x, name=name)

    return model

# %% [markdown]
# **1) Plain-34**

# %%
plain_34 = build_plain(input_shape=(224,224,3), is_50=False, activation='relu', name='Plain_34')
plain_34.summary()
# Out:
# Model: "Plain_34"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d_89 (Conv2D)          (None, 112, 112, 64)      9472
#
#  batch_normalization_89 (Ba  (None, 112, 112, 64)      256
#  tchNormalization)
#
#  activation_82 (Activation)  (None, 112, 112, 64)      0
#
#  max_pooling2d_2 (MaxPoolin  (None, 56, 56, 64)        0
#  g2D)
#
#  conv2d_90 (Conv2D)          (None, 56, 56, 64)        36928
#
#  batch_normalization_90 (Ba  (None, 56, 56, 64)        256
#  tchNormalization)
#
#  activation_83 (Activation)  (None, 56, 56, 64)        0
#
#  conv2d_91 (Conv2D)          (None, 56, 56, 64)        36928
#
#  batch_normalization_91 (Ba  (None, 56, 56, 64)        256
#  tchNormalization)
#
#  activation_84 (Activation)  (None, 56, 56, 64)        0
#
#  conv2d_92 (Conv2D)          (None, 56, 56, 64)        36928
#
#  batch_normalization_92 (Ba  (None, 56, 56, 64)        256
#  tchNormalization)
#
#  activation_85 (Activation)  (None, 56, 56, 64)        0
#
#  conv2d_93 (Conv2D)          (None, 56, 56, 64)        36928
#
#  batch_normalization_93 (Ba  (None, 56, 56, 64)        256
#  tchNormalization)
#
#  activation_86 (Activation)  (None, 56, 56, 64)        0
#
#  conv2d_94 (Conv2D)          (None, 56, 56, 64)        36928
#
#  batch_normalization_94 (Ba  (None, 56, 56, 64)        256
#  tchNormalization)
#
#  activation_87 (Activation)  (None, 56, 56, 64)        0
#
#  conv2d_95 (Conv2D)          (None, 56, 56, 64)        36928
#
#  batch_normalization_95 (Ba  (None, 56, 56, 64)        256
#  tchNormalization)
#
#  activation_88 (Activation)  (None, 56, 56, 64)        0
#
#  conv2d_96 (Conv2D)          (None, 28, 28, 128)       73856
#
#  batch_normalization_96 (Ba  (None, 28, 28, 128)       512
#  tchNormalization)
#
#  activation_89 (Activation)  (None, 28, 28, 128)       0
#
#  conv2d_97 (Conv2D)          (None, 28, 28, 128)       147584
#
#  batch_normalization_97 (Ba  (None, 28, 28, 128)       512
#  tchNormalization)
#
#  activation_90 (Activation)  (None, 28, 28, 128)       0
#
#  conv2d_98 (Conv2D)          (None, 28, 28, 128)       147584
#
#  batch_normalization_98 (Ba  (None, 28, 28, 128)       512
#  tchNormalization)
#
#  activation_91 (Activation)  (None, 28, 28, 128)       0
#
#  conv2d_99 (Conv2D)          (None, 28, 28, 128)       147584
#
#  batch_normalization_99 (Ba  (None, 28, 28, 128)       512
#  tchNormalization)
#
#  activation_92 (Activation)  (None, 28, 28, 128)       0
#
#  conv2d_100 (Conv2D)         (None, 28, 28, 128)       147584
#
#  batch_normalization_100 (B  (None, 28, 28, 128)       512
#  atchNormalization)
#
#  activation_93 (Activation)  (None, 28, 28, 128)       0
#
#  conv2d_101 (Conv2D)         (None, 28, 28, 128)       147584
#
#  batch_normalization_101 (B  (None, 28, 28, 128)       512
#  atchNormalization)
#
#  activation_94 (Activation)  (None, 28, 28, 128)       0
#
#  conv2d_102 (Conv2D)         (None, 28, 28, 128)       147584
#
#  batch_normalization_102 (B  (None, 28, 28, 128)       512
#  atchNormalization)
#
#  activation_95 (Activation)  (None, 28, 28, 128)       0
#
#  conv2d_103 (Conv2D)         (None, 28, 28, 128)       147584
#
#  batch_normalization_103 (B  (None, 28, 28, 128)       512
#  atchNormalization)
#
#  activation_96 (Activation)  (None, 28, 28, 128)       0
#
#  conv2d_104 (Conv2D)         (None, 14, 14, 256)       295168
#
#  batch_normalization_104 (B  (None, 14, 14, 256)       1024
#  atchNormalization)
#
#  activation_97 (Activation)  (None, 14, 14, 256)       0
#
#  conv2d_105 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_105 (B  (None, 14, 14, 256)       1024
#  atchNormalization)
#
#  activation_98 (Activation)  (None, 14, 14, 256)       0
#
#  conv2d_106 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_106 (B  (None, 14, 14, 256)       1024
#  atchNormalization)
#
#  activation_99 (Activation)  (None, 14, 14, 256)       0
#
#  conv2d_107 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_107 (B  (None, 14, 14, 256)       1024
#  atchNormalization)
#
#  activation_100 (Activation  (None, 14, 14, 256)       0
#  )
#
#  conv2d_108 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_108 (B  (None, 14, 14, 256)       1024
#  atchNormalization)
#
#  activation_101 (Activation  (None, 14, 14, 256)       0
#  )
#
#  conv2d_109 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_109 (B  (None, 14, 14, 256)       1024
#  atchNormalization)
#
#  activation_102 (Activation  (None, 14, 14, 256)       0
#  )
#
#  conv2d_110 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_110 (B  (None, 14, 14, 256)       1024
#  atchNormalization)
#
#  activation_103 (Activation  (None, 14, 14, 256)       0
#  )
#
#  conv2d_111 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_111 (B  (None, 14, 14, 256)       1024
#  atchNormalization)
#
#  activation_104 (Activation  (None, 14, 14, 256)       0
#  )
#
#  conv2d_112 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_112 (B  (None, 14, 14, 256)       1024
#  atchNormalization)
#
#  activation_105 (Activation  (None, 14, 14, 256)       0
#  )
#
#  conv2d_113 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_113 (B  (None, 14, 14, 256)       1024
#  atchNormalization)
#
#  activation_106 (Activation  (None, 14, 14, 256)       0
#  )
#
#  conv2d_114 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_114 (B  (None, 14, 14, 256)       1024
#  atchNormalization)
#
#  activation_107 (Activation  (None, 14, 14, 256)       0
#  )
#
#  conv2d_115 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_115 (B  (None, 14, 14, 256)       1024
#  atchNormalization)
#
#  activation_108 (Activation  (None, 14, 14, 256)       0
#  )
#
#  conv2d_116 (Conv2D)         (None, 7, 7, 512)         1180160
#
#  batch_normalization_116 (B  (None, 7, 7, 512)         2048
#  atchNormalization)
#
#  activation_109 (Activation  (None, 7, 7, 512)         0
#  )
#
#  conv2d_117 (Conv2D)         (None, 7, 7, 512)         2359808
#
#  batch_normalization_117 (B  (None, 7, 7, 512)         2048
#  atchNormalization)
#
#  activation_110 (Activation  (None, 7, 7, 512)         0
#  )
#
#  conv2d_118 (Conv2D)         (None, 7, 7, 512)         2359808
#
#  batch_normalization_118 (B  (None, 7, 7, 512)         2048
#  atchNormalization)
#
#  activation_111 (Activation  (None, 7, 7, 512)         0
#  )
#
#  conv2d_119 (Conv2D)         (None, 7, 7, 512)         2359808
#
#  batch_normalization_119 (B  (None, 7, 7, 512)         2048
#  atchNormalization)
#
#  activation_112 (Activation  (None, 7, 7, 512)         0
#  )
#
#  conv2d_120 (Conv2D)         (None, 7, 7, 512)         2359808
#
#  batch_normalization_120 (B  (None, 7, 7, 512)         2048
#  atchNormalization)
#
#  activation_113 (Activation  (None, 7, 7, 512)         0
#  )
#
#  conv2d_121 (Conv2D)         (None, 7, 7, 512)         2359808
#
#  batch_normalization_121 (B  (None, 7, 7, 512)         2048
#  atchNormalization)
#
#  activation_114 (Activation  (None, 7, 7, 512)         0
#  )
#
#  global_average_pooling2d_2  (None, 512)               0
#   (GlobalAveragePooling2D)
#
#  dense_2 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 21134722 (80.62 MB)
# Trainable params: 21119490 (80.56 MB)
# Non-trainable params: 15232 (59.50 KB)
# _________________________________________________________________

# %% [markdown]
# **1) Plain-50**

# %%
plain_50 = build_plain(input_shape=(224,224,3), is_50=True, activation='relu', name='Plain_50')
plain_50.summary()
# Out:
# Model: "Plain_50"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d_122 (Conv2D)         (None, 112, 112, 64)      9472
#
#  batch_normalization_122 (B  (None, 112, 112, 64)      256
#  atchNormalization)
#
#  activation_115 (Activation  (None, 112, 112, 64)      0
#  )
#
#  max_pooling2d_3 (MaxPoolin  (None, 56, 56, 64)        0
#  g2D)
#
#  conv2d_123 (Conv2D)         (None, 56, 56, 64)        4160
#
#  batch_normalization_123 (B  (None, 56, 56, 64)        256
#  atchNormalization)
#
#  activation_116 (Activation  (None, 56, 56, 64)        0
#  )
#
#  conv2d_124 (Conv2D)         (None, 56, 56, 64)        36928
#
#  batch_normalization_124 (B  (None, 56, 56, 64)        256
#  atchNormalization)
#
#  activation_117 (Activation  (None, 56, 56, 64)        0
#  )
#
#  conv2d_125 (Conv2D)         (None, 56, 56, 256)       16640
#
#  batch_normalization_125 (B  (None, 56, 56, 256)       1024
#  atchNormalization)
#
#  activation_118 (Activation  (None, 56, 56, 256)       0
#  )
#
#  conv2d_126 (Conv2D)         (None, 56, 56, 64)        16448
#
#  batch_normalization_126 (B  (None, 56, 56, 64)        256
#  atchNormalization)
#
#  activation_119 (Activation  (None, 56, 56, 64)        0
#  )
#
#  conv2d_127 (Conv2D)         (None, 56, 56, 64)        36928
#
#  batch_normalization_127 (B  (None, 56, 56, 64)        256
#  atchNormalization)
#
#  activation_120 (Activation  (None, 56, 56, 64)        0
#  )
#
#  conv2d_128 (Conv2D)         (None, 56, 56, 256)       16640
#
#  batch_normalization_128 (B  (None, 56, 56, 256)       1024
#  atchNormalization)
#
#  activation_121 (Activation  (None, 56, 56, 256)       0
#  )
#
#  conv2d_129 (Conv2D)         (None, 56, 56, 64)        16448
#
#  batch_normalization_129 (B  (None, 56, 56, 64)        256
#  atchNormalization)
#
#  activation_122 (Activation  (None, 56, 56, 64)        0
#  )
#
#  conv2d_130 (Conv2D)         (None, 56, 56, 64)        36928
#
#  batch_normalization_130 (B  (None, 56, 56, 64)        256
#  atchNormalization)
#
#  activation_123 (Activation  (None, 56, 56, 64)        0
#  )
#
#  conv2d_131 (Conv2D)         (None, 56, 56, 256)       16640
#
#  batch_normalization_131 (B  (None, 56, 56, 256)       1024
#  atchNormalization)
#
#  activation_124 (Activation  (None, 56, 56, 256)       0
#  )
#
#  conv2d_132 (Conv2D)         (None, 28, 28, 128)       32896
#
#  batch_normalization_132 (B  (None, 28, 28, 128)       512
#  atchNormalization)
#
#  activation_125 (Activation  (None, 28, 28, 128)       0
#  )
#
#  conv2d_133 (Conv2D)         (None, 28, 28, 128)       147584
#
#  batch_normalization_133 (B  (None, 28, 28, 128)       512
#  atchNormalization)
#
#  activation_126 (Activation  (None, 28, 28, 128)       0
#  )
#
#  conv2d_134 (Conv2D)         (None, 28, 28, 512)       66048
#
#  batch_normalization_134 (B  (None, 28, 28, 512)       2048
#  atchNormalization)
#
#  activation_127 (Activation  (None, 28, 28, 512)       0
#  )
#
#  conv2d_135 (Conv2D)         (None, 28, 28, 128)       65664
#
#  batch_normalization_135 (B  (None, 28, 28, 128)       512
#  atchNormalization)
#
#  activation_128 (Activation  (None, 28, 28, 128)       0
#  )
#
#  conv2d_136 (Conv2D)         (None, 28, 28, 128)       147584
#
#  batch_normalization_136 (B  (None, 28, 28, 128)       512
#  atchNormalization)
#
#  activation_129 (Activation  (None, 28, 28, 128)       0
#  )
#
#  conv2d_137 (Conv2D)         (None, 28, 28, 512)       66048
#
#  batch_normalization_137 (B  (None, 28, 28, 512)       2048
#  atchNormalization)
#
#  activation_130 (Activation  (None, 28, 28, 512)       0
#  )
#
#  conv2d_138 (Conv2D)         (None, 28, 28, 128)       65664
#
#  batch_normalization_138 (B  (None, 28, 28, 128)       512
#  atchNormalization)
#
#  activation_131 (Activation  (None, 28, 28, 128)       0
#  )
#
#  conv2d_139 (Conv2D)         (None, 28, 28, 128)       147584
#
#  batch_normalization_139 (B  (None, 28, 28, 128)       512
#  atchNormalization)
#
#  activation_132 (Activation  (None, 28, 28, 128)       0
#  )
#
#  conv2d_140 (Conv2D)         (None, 28, 28, 512)       66048
#
#  batch_normalization_140 (B  (None, 28, 28, 512)       2048
#  atchNormalization)
#
#  activation_133 (Activation  (None, 28, 28, 512)       0
#  )
#
#  conv2d_141 (Conv2D)         (None, 28, 28, 128)       65664
#
#  batch_normalization_141 (B  (None, 28, 28, 128)       512
#  atchNormalization)
#
#  activation_134 (Activation  (None, 28, 28, 128)       0
#  )
#
#  conv2d_142 (Conv2D)         (None, 28, 28, 128)       147584
#
#  batch_normalization_142 (B  (None, 28, 28, 128)       512
#  atchNormalization)
#
#  activation_135 (Activation  (None, 28, 28, 128)       0
#  )
#
#  conv2d_143 (Conv2D)         (None, 28, 28, 512)       66048
#
#  batch_normalization_143 (B  (None, 28, 28, 512)       2048
#  atchNormalization)
#
#  activation_136 (Activation  (None, 28, 28, 512)       0
#  )
#
#  conv2d_144 (Conv2D)         (None, 14, 14, 256)       131328
#
#  batch_normalization_144 (B  (None, 14, 14, 256)       1024
#  atchNormalization)
#
#  activation_137 (Activation  (None, 14, 14, 256)       0
#  )
#
#  conv2d_145 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_145 (B  (None, 14, 14, 256)       1024
#  atchNormalization)
#
#  activation_138 (Activation  (None, 14, 14, 256)       0
#  )
#
#  conv2d_146 (Conv2D)         (None, 14, 14, 1024)      263168
#
#  batch_normalization_146 (B  (None, 14, 14, 1024)      4096
#  atchNormalization)
#
#  activation_139 (Activation  (None, 14, 14, 1024)      0
#  )
#
#  conv2d_147 (Conv2D)         (None, 14, 14, 256)       262400
#
#  batch_normalization_147 (B  (None, 14, 14, 256)       1024
#  atchNormalization)
#
#  activation_140 (Activation  (None, 14, 14, 256)       0
#  )
#
#  conv2d_148 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_148 (B  (None, 14, 14, 256)       1024
#  atchNormalization)
#
#  activation_141 (Activation  (None, 14, 14, 256)       0
#  )
#
#  conv2d_149 (Conv2D)         (None, 14, 14, 1024)      263168
#
#  batch_normalization_149 (B  (None, 14, 14, 1024)      4096
#  atchNormalization)
#
#  activation_142 (Activation  (None, 14, 14, 1024)      0
#  )
#
#  conv2d_150 (Conv2D)         (None, 14, 14, 256)       262400
#
#  batch_normalization_150 (B  (None, 14, 14, 256)       1024
#  atchNormalization)
#
#  activation_143 (Activation  (None, 14, 14, 256)       0
#  )
#
#  conv2d_151 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_151 (B  (None, 14, 14, 256)       1024
#  atchNormalization)
#
#  activation_144 (Activation  (None, 14, 14, 256)       0
#  )
#
#  conv2d_152 (Conv2D)         (None, 14, 14, 1024)      263168
#
#  batch_normalization_152 (B  (None, 14, 14, 1024)      4096
#  atchNormalization)
#
#  activation_145 (Activation  (None, 14, 14, 1024)      0
#  )
#
#  conv2d_153 (Conv2D)         (None, 14, 14, 256)       262400
#
#  batch_normalization_153 (B  (None, 14, 14, 256)       1024
#  atchNormalization)
#
#  activation_146 (Activation  (None, 14, 14, 256)       0
#  )
#
#  conv2d_154 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_154 (B  (None, 14, 14, 256)       1024
#  atchNormalization)
#
#  activation_147 (Activation  (None, 14, 14, 256)       0
#  )
#
#  conv2d_155 (Conv2D)         (None, 14, 14, 1024)      263168
#
#  batch_normalization_155 (B  (None, 14, 14, 1024)      4096
#  atchNormalization)
#
#  activation_148 (Activation  (None, 14, 14, 1024)      0
#  )
#
#  conv2d_156 (Conv2D)         (None, 14, 14, 256)       262400
#
#  batch_normalization_156 (B  (None, 14, 14, 256)       1024
#  atchNormalization)
#
#  activation_149 (Activation  (None, 14, 14, 256)       0
#  )
#
#  conv2d_157 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_157 (B  (None, 14, 14, 256)       1024
#  atchNormalization)
#
#  activation_150 (Activation  (None, 14, 14, 256)       0
#  )
#
#  conv2d_158 (Conv2D)         (None, 14, 14, 1024)      263168
#
#  batch_normalization_158 (B  (None, 14, 14, 1024)      4096
#  atchNormalization)
#
#  activation_151 (Activation  (None, 14, 14, 1024)      0
#  )
#
#  conv2d_159 (Conv2D)         (None, 14, 14, 256)       262400
#
#  batch_normalization_159 (B  (None, 14, 14, 256)       1024
#  atchNormalization)
#
#  activation_152 (Activation  (None, 14, 14, 256)       0
#  )
#
#  conv2d_160 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_160 (B  (None, 14, 14, 256)       1024
#  atchNormalization)
#
#  activation_153 (Activation  (None, 14, 14, 256)       0
#  )
#
#  conv2d_161 (Conv2D)         (None, 14, 14, 1024)      263168
#
#  batch_normalization_161 (B  (None, 14, 14, 1024)      4096
#  atchNormalization)
#
#  activation_154 (Activation  (None, 14, 14, 1024)      0
#  )
#
#  conv2d_162 (Conv2D)         (None, 7, 7, 512)         524800
#
#  batch_normalization_162 (B  (None, 7, 7, 512)         2048
#  atchNormalization)
#
#  activation_155 (Activation  (None, 7, 7, 512)         0
#  )
#
#  conv2d_163 (Conv2D)         (None, 7, 7, 512)         2359808
#
#  batch_normalization_163 (B  (None, 7, 7, 512)         2048
#  atchNormalization)
#
#  activation_156 (Activation  (None, 7, 7, 512)         0
#  )
#
#  conv2d_164 (Conv2D)         (None, 7, 7, 2048)        1050624
#
#  batch_normalization_164 (B  (None, 7, 7, 2048)        8192
#  atchNormalization)
#
#  activation_157 (Activation  (None, 7, 7, 2048)        0
#  )
#
#  conv2d_165 (Conv2D)         (None, 7, 7, 512)         1049088
#
#  batch_normalization_165 (B  (None, 7, 7, 512)         2048
#  atchNormalization)
#
#  activation_158 (Activation  (None, 7, 7, 512)         0
#  )
#
#  conv2d_166 (Conv2D)         (None, 7, 7, 512)         2359808
#
#  batch_normalization_166 (B  (None, 7, 7, 512)         2048
#  atchNormalization)
#
#  activation_159 (Activation  (None, 7, 7, 512)         0
#  )
#
#  conv2d_167 (Conv2D)         (None, 7, 7, 2048)        1050624
#
#  batch_normalization_167 (B  (None, 7, 7, 2048)        8192
#  atchNormalization)
#
#  activation_160 (Activation  (None, 7, 7, 2048)        0
#  )
#
#  conv2d_168 (Conv2D)         (None, 7, 7, 512)         1049088
#
#  batch_normalization_168 (B  (None, 7, 7, 512)         2048
#  atchNormalization)
#
#  activation_161 (Activation  (None, 7, 7, 512)         0
#  )
#
#  conv2d_169 (Conv2D)         (None, 7, 7, 512)         2359808
#
#  batch_normalization_169 (B  (None, 7, 7, 512)         2048
#  atchNormalization)
#
#  activation_162 (Activation  (None, 7, 7, 512)         0
#  )
#
#  conv2d_170 (Conv2D)         (None, 7, 7, 2048)        1050624
#
#  batch_normalization_170 (B  (None, 7, 7, 2048)        8192
#  atchNormalization)
#
#  activation_163 (Activation  (None, 7, 7, 2048)        0
#  )
#
#  global_average_pooling2d_3  (None, 2048)              0
#   (GlobalAveragePooling2D)
#
#  dense_3 (Dense)             (None, 2)                 4098
#
# =================================================================
# Total params: 20803714 (79.36 MB)
# Trainable params: 20758274 (79.19 MB)
# Non-trainable params: 45440 (177.50 KB)
# _________________________________________________________________

# %% [markdown]
# ### Ablation Study 실습 (4) ResNet vs PlainNet

# %% [markdown]
# 이제 본격적으로 위에서 준비한 데이터셋과 모델의 성능 비교를 위해서 모델을 훈련하고 평가하자.

# %%
BATCH_SIZE = 16
EPOCH = 10

# %%
# 데이터 정의

ds_train = apply_normalize_on_dataset(ds_train, batch_size=BATCH_SIZE)
ds_test = apply_normalize_on_dataset(ds_test, batch_size=BATCH_SIZE)

# %%
# Plain-34 학습


plain_34.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01, clipnorm=1.),
    metrics=['accuracy'],
)

history_plain_34 = plain_34.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train[:80%]'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['train[80%:]'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Epoch 1/10
# 1163/1163 [==============================] - 166s 118ms/step - loss: 2.2302 - accuracy: 0.5049 - val_loss: 2.2092 - val_accuracy: 0.4821
# Epoch 2/10
# 1163/1163 [==============================] - 137s 118ms/step - loss: 2.2056 - accuracy: 0.5035 - val_loss: 2.2021 - val_accuracy: 0.4875
# Epoch 3/10
# 1163/1163 [==============================] - 143s 123ms/step - loss: 2.1986 - accuracy: 0.5032 - val_loss: 2.2002 - val_accuracy: 0.4944
# Epoch 4/10
# 1163/1163 [==============================] - 144s 124ms/step - loss: 2.1916 - accuracy: 0.5035 - val_loss: 2.1939 - val_accuracy: 0.4899
# Epoch 5/10
# 1163/1163 [==============================] - 143s 123ms/step - loss: 2.1846 - accuracy: 0.5040 - val_loss: 2.1812 - val_accuracy: 0.4897
# Epoch 6/10
# 1163/1163 [==============================] - 143s 123ms/step - loss: 2.1778 - accuracy: 0.5051 - val_loss: 2.1743 - val_accuracy: 0.4836
# Epoch 7/10
# 1163/1163 [==============================] - 134s 116ms/step - loss: 2.1709 - accuracy: 0.5030 - val_loss: 2.1674 - val_accuracy: 0.4879
# Epoch 8/10
# 1163/1163 [==============================] - 143s 123ms/step - loss: 2.1646 - accuracy: 0.5040 - val_loss: 2.1631 - val_accuracy: 0.4858
# Epoch 9/10
# 1163/1163 [==============================] - 134s 116ms/step - loss: 2.1572 - accuracy: 0.5043 - val_loss: 2.1622 - val_accuracy: 0.4886
# Epoch 10/10
# 1163/1163 [==============================] - 134s 115ms/step - loss: 2.1504 - accuracy: 0.5046 - val_loss: 2.1552 - val_accuracy: 0.4959

# %%
# ResNet-34 학습


resnet_34.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01, clipnorm=1.),
    metrics=['accuracy'],
)

history_resnet_34 = resnet_34.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train[:80%]'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['train[80%:]'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Epoch 1/10
# 1163/1163 [==============================] - 160s 122ms/step - loss: 2.3919 - accuracy: 0.5051 - val_loss: 2.3879 - val_accuracy: 0.4884
# Epoch 2/10
# 1163/1163 [==============================] - 142s 122ms/step - loss: 2.3840 - accuracy: 0.5027 - val_loss: 2.3800 - val_accuracy: 0.4875
# Epoch 3/10
# 1163/1163 [==============================] - 142s 122ms/step - loss: 2.3761 - accuracy: 0.5046 - val_loss: 2.3722 - val_accuracy: 0.4933
# Epoch 4/10
# 1163/1163 [==============================] - 141s 122ms/step - loss: 2.3683 - accuracy: 0.5042 - val_loss: 2.3644 - val_accuracy: 0.4858
# Epoch 5/10
# 1163/1163 [==============================] - 142s 122ms/step - loss: 2.3605 - accuracy: 0.5028 - val_loss: 2.3567 - val_accuracy: 0.4810
# Epoch 6/10
# 1163/1163 [==============================] - 149s 128ms/step - loss: 2.3528 - accuracy: 0.5026 - val_loss: 2.3489 - val_accuracy: 0.4873
# Epoch 7/10
# 1163/1163 [==============================] - 141s 121ms/step - loss: 2.3451 - accuracy: 0.5063 - val_loss: 2.3413 - val_accuracy: 0.4823
# Epoch 8/10
# 1163/1163 [==============================] - 150s 129ms/step - loss: 2.3374 - accuracy: 0.5054 - val_loss: 2.3336 - val_accuracy: 0.4929
# Epoch 9/10
# 1163/1163 [==============================] - 142s 122ms/step - loss: 2.3298 - accuracy: 0.5025 - val_loss: 2.3260 - val_accuracy: 0.4875
# Epoch 10/10
# 1163/1163 [==============================] - 148s 127ms/step - loss: 2.3222 - accuracy: 0.5040 - val_loss: 2.3184 - val_accuracy: 0.4944

# %%
# Plain-50 학습

plain_50.compile(
    loss='binary_crossentropy',
    optimizer=keras.optimizers.SGD(lr=0.01, clipnorm=1.),
    metrics=['accuracy'],
)

history_plain_50 = plain_50.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train[:80%]'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['train[80%:]'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Epoch 1/10
# 1163/1163 [==============================] - 222s 170ms/step - loss: 5.7098 - accuracy: 0.4989 - val_loss: 6.2565 - val_accuracy: 0.5132
# Epoch 2/10
# 1163/1163 [==============================] - 200s 172ms/step - loss: 5.6977 - accuracy: 0.4942 - val_loss: 6.3343 - val_accuracy: 0.4821
# Epoch 3/10
# 1163/1163 [==============================] - 195s 168ms/step - loss: 5.7006 - accuracy: 0.4997 - val_loss: 6.1965 - val_accuracy: 0.4756
# Epoch 4/10
# 1163/1163 [==============================] - 199s 171ms/step - loss: 5.6951 - accuracy: 0.5029 - val_loss: 8.6311 - val_accuracy: 0.4862
# Epoch 5/10
# 1163/1163 [==============================] - 199s 171ms/step - loss: 5.6526 - accuracy: 0.4945 - val_loss: 5.6626 - val_accuracy: 0.5101
# Epoch 6/10
# 1163/1163 [==============================] - 200s 172ms/step - loss: 5.6589 - accuracy: 0.4983 - val_loss: 5.8903 - val_accuracy: 0.5129
# Epoch 7/10
# 1163/1163 [==============================] - 196s 168ms/step - loss: 5.6282 - accuracy: 0.5015 - val_loss: 6.5051 - val_accuracy: 0.5039
# Epoch 8/10
# 1163/1163 [==============================] - 196s 168ms/step - loss: 5.7070 - accuracy: 0.5027 - val_loss: 5.4252 - val_accuracy: 0.5082
# Epoch 9/10
# 1163/1163 [==============================] - 196s 168ms/step - loss: 5.6213 - accuracy: 0.5021 - val_loss: 5.5465 - val_accuracy: 0.5101
# Epoch 10/10
# 1163/1163 [==============================] - 196s 168ms/step - loss: 5.6042 - accuracy: 0.5048 - val_loss: 5.7438 - val_accuracy: 0.4873

# %%
# ResNet-50 학습


resnet_50.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01, clipnorm=1.),
    metrics=['accuracy'],
)

history_resnet_50 = resnet_50.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train[:80%]'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['train[80%:]'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Epoch 1/10
# 1163/1163 [==============================] - 149s 106ms/step - loss: 5.9952 - accuracy: 0.5050 - val_loss: 5.9815 - val_accuracy: 0.4922
# Epoch 2/10
# 1163/1163 [==============================] - 123s 106ms/step - loss: 5.9699 - accuracy: 0.5032 - val_loss: 5.9569 - val_accuracy: 0.4881
# Epoch 3/10
# 1163/1163 [==============================] - 112s 96ms/step - loss: 5.9447 - accuracy: 0.5044 - val_loss: 5.9325 - val_accuracy: 0.4864
# Epoch 4/10
# 1163/1163 [==============================] - 112s 96ms/step - loss: 5.9204 - accuracy: 0.5033 - val_loss: 5.9082 - val_accuracy: 0.4918
# Epoch 5/10
# 1163/1163 [==============================] - 121s 104ms/step - loss: 5.8961 - accuracy: 0.5033 - val_loss: 5.8840 - val_accuracy: 0.4884
# Epoch 6/10
# 1163/1163 [==============================] - 112s 96ms/step - loss: 5.8720 - accuracy: 0.5038 - val_loss: 5.8599 - val_accuracy: 0.4875
# Epoch 7/10
# 1163/1163 [==============================] - 121s 104ms/step - loss: 5.8479 - accuracy: 0.5061 - val_loss: 5.8359 - val_accuracy: 0.4871
# Epoch 8/10
# 1163/1163 [==============================] - 112s 96ms/step - loss: 5.8240 - accuracy: 0.5046 - val_loss: 5.8121 - val_accuracy: 0.4888
# Epoch 9/10
# 1163/1163 [==============================] - 113s 97ms/step - loss: 5.8002 - accuracy: 0.5019 - val_loss: 5.7883 - val_accuracy: 0.4814
# Epoch 10/10
# 1163/1163 [==============================] - 113s 97ms/step - loss: 5.7765 - accuracy: 0.5052 - val_loss: 5.7647 - val_accuracy: 0.4879

# %% [markdown]
# 이제 Resnet과 Plain을 그래프를 그리고 비교해보자.
#
# 먼저 손실(loss)이 어떻게 다르게 진행되는지 비교해보자.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

# Training Loss 그래프
plt.plot(history_resnet_34.history['loss'], 'r', label='ResNet_34 Training Loss')
plt.plot(history_resnet_50.history['loss'], 'b', label='ResNet_50 Training Loss')
plt.plot(history_plain_34.history['loss'], 'y', label='Plain_34 Training Loss')
plt.plot(history_plain_50.history['loss'], 'g', label='Plain_50 Training Loss')

# Validation Loss 그래프
plt.plot(history_resnet_34.history['val_loss'], 'r', marker='o', label='ResNet_34 Validation Loss')
plt.plot(history_resnet_50.history['val_loss'], 'b', marker='o', label='ResNet_50 Validation Loss')
plt.plot(history_plain_34.history['val_loss'], 'y', marker='o', label='Plain_34 Validation Loss')
plt.plot(history_plain_50.history['val_loss'], 'g', marker='o', label='Plain_50 Validation Loss')

plt.title('Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# 그리고 정확도(accuracy)도 비교해 보자.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

# Training Accuracy 그래프
plt.plot(history_resnet_34.history['accuracy'], 'r', label='ResNet_34 Training Accuracy')
plt.plot(history_resnet_50.history['accuracy'], 'b', label='ResNet_50 Training Accuracy')
plt.plot(history_plain_34.history['accuracy'], 'y', label='Plain_34 Training Accuracy')
plt.plot(history_plain_50.history['accuracy'], 'g', label='Plain_50 Training Accuracy')

# Validation Accuracy 그래프
plt.plot(history_resnet_34.history['val_accuracy'], 'r', marker='o', label='ResNet_34 Validation Accuracy')
plt.plot(history_resnet_50.history['val_accuracy'], 'b', marker='o', label='ResNet_50 Validation Accuracy')
plt.plot(history_plain_34.history['val_accuracy'], 'y', marker='o', label='Plain_34 Validation Accuracy')
plt.plot(history_plain_50.history['val_accuracy'], 'g', marker='o', label='Plain_50 Validation Accuracy')

plt.title('Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ## 회고
#
# 이진 분류라 loss='binary_crossentropy'로 진행했는데 정확도가 너무 떨어져서,
# loss='sparse_categorical_crossentropy'로 다시 진행했다.
#
# 왜 이렇게 해야 더 정확도가 올라가는지 궁금하다.
#
# => sigmoid를 사용하지 않았기 때문에,,
#
# 왜?! Resnet이 성능이 더 낮을까..
#
# => 아마도 에폭을 적게 돌려서 그런거 같다.. 에폭 더 돌려봐야할 거 같다.
#
# loss도 잘 안 줄어드는 것을 보니 에폭을 더 늘려야할 거 같다.
